# %% [markdown]
# # Question 1-4

# %% [markdown]
# ## Importing libraries

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.cluster.hierarchy as sch

# %% [markdown]
# ### Ploting the clusters in of first two attributes

# %%
# Visualising the clusters
def visualize(X, clusters):
    plt.scatter(X[clusters == 0, 0], X[clusters == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
    plt.scatter(X[clusters == 1, 0], X[clusters == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
    plt.scatter(X[clusters == 2, 0], X[clusters == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
    plt.scatter(X[clusters == 3, 0], X[clusters == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
    plt.scatter(X[clusters == 4, 0], X[clusters == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
    plt.title('Clusters of customers')
    plt.xlabel('Annual Income (k$)')
    plt.ylabel('Spending Score (1-100)')
    plt.legend()
    plt.show()

# %% [markdown]
# ### Dendrogram

# %%
# Using the dendrogram to find the optimal number of clusters
def dendrogram(X):
    dendrogram = sch.dendrogram(sch.linkage(X, method = 'single'))
    plt.title('Dendrogram')
    plt.xlabel('Customers')
    plt.ylabel('Euclidean distances')
    plt.show()

# %% [markdown]
# ### Piechart plotter

# %%
def pieplotter(labels, sizes):
    plt.figure(num=None, figsize=(6, 4), dpi=150, facecolor='c', edgecolor='k')
    
    colors = ['lightcoral','gold', 'yellowgreen','lightskyblue', 'red','blue']
    patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
    plt.legend( loc = 'best', labels=['%s, %1.1f %%' % (l, 100*s/sum(sizes)) for l, s in zip(labels, sizes)])
    
    plt.axis('equal')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Reading the data set

# %%
# Importing the dataset
dataSet = pd.read_csv("./../output_data/q-1-1_a_linear.csv")
Class = "xAttack"
X = dataSet.iloc[:,:-1].values

# %%
X
# Out:
# array([[ 0.00000000e+00,  7.56415710e-01,  1.44824627e+00, ...,
#          2.58068225e-01, -4.70689824e-01, -3.93873871e-02],
#        [ 1.00000000e+00, -3.18537870e-01,  3.99413534e-01, ...,
#         -1.64394836e+00,  1.98723003e+00,  9.06077912e-01],
#        [ 2.00000000e+00,  6.08745751e-01,  1.51918151e+00, ...,
#          4.03279661e-01, -4.18085870e-01,  1.50767595e-02],
#        ...,
#        [ 2.49950000e+04,  1.90469747e+00, -1.36036669e+00, ...,
#         -9.33988526e+00,  1.10118985e+01, -1.10554321e+01],
#        [ 2.49960000e+04,  2.19467358e+00,  2.28388771e+00, ...,
#          2.02095732e+00, -6.61930722e-01,  1.44369583e-02],
#        [ 2.49970000e+04, -1.02371568e+00, -2.62763109e+00, ...,
#         -5.93051162e-01, -1.89931164e-01,  1.05619331e+00]])

# %% [markdown]
# ### setting parameters

# %%
K = 5

# %%
# dendrogram(X)

# %% [markdown]
# ### AgglomerativeClustering using sklearn

# %%
# Fitting Hierarchical Clustering to the dataset
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = K, affinity = 'euclidean', linkage = 'single')
clusters = hc.fit_predict(X)

# %%
visualize(X,clusters)

# %%
clusters
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
max_sum = 0
for i in range(K):
    clValue,counts = np.unique(dataSet[Class][clusters == i],return_counts=True) 
    pieplotter(clValue, counts)
    print(i,clValue,counts)
    max_sum += max(counts)
purity = max_sum/dataSet.shape[0]
    
purity
# Out:
# 0 ['dos' 'normal' 'probe' 'r2l' 'u2r'] [ 9114 13362  2311   197    10]
# 1 ['probe'] [1]
# 2 ['normal'] [1]
# 3 ['probe'] [1]
# 4 ['normal'] [1]
# 0.5346827746219698

# %% [markdown]
# ### Reading the data set

# %%
# Importing the dataset
dataSet = pd.read_csv("./../output_data/q-1-1_b_sigmoid.csv")
Class = "xAttack"
X = dataSet.iloc[:,:-1].values

# %%
X
# Out:
# array([[0.00000000e+00, 5.08228096e-01, 5.46591043e-01, ...,
#         5.44153985e-01, 6.07429560e-01, 5.59164054e-01],
#        [1.00000000e+00, 5.06881415e-01, 5.45917771e-01, ...,
#         5.42698900e-01, 6.04378614e-01, 5.51253614e-01],
#        [2.00000000e+00, 5.08349752e-01, 5.46872599e-01, ...,
#         5.44290106e-01, 6.07528402e-01, 5.59142231e-01],
#        ...,
#        [2.49950000e+04, 5.06550032e-01, 5.38457441e-01, ...,
#         5.40107107e-01, 6.00612566e-01, 5.48811833e-01],
#        [2.49960000e+04, 5.10520440e-01, 5.49641850e-01, ...,
#         5.46349688e-01, 6.06283989e-01, 5.59094163e-01],
#        [2.49970000e+04, 5.08931809e-01, 5.47273953e-01, ...,
#         5.44380779e-01, 6.06715872e-01, 5.54310062e-01]])

# %% [markdown]
# ### setting parameters

# %%
K = 5

# %%
# dendrogram(X)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-44f5d7bf2c96> in <module>
#       1 # Using the dendrogram to find the optimal number of clusters
#       2 import scipy.cluster.hierarchy as sch
# ----> 3 dendrogram = sch.dendrogram(sch.linkage(X, method = 'single'))
#       4 plt.title('Dendrogram')
#       5 plt.xlabel('Customers')
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/cluster/hierarchy.py in dendrogram(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, no_plot, no_labels, leaf_font_size, leaf_rotation, leaf_label_func, show_contracted, link_color_func, ax, above_threshold_color)
#    2509                          contraction_marks=contraction_marks,
#    2510                          ax=ax,
# -> 2511                          above_threshold_color=above_threshold_color)
#    2512
#    2513     return R
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/cluster/hierarchy.py in _plot_dendrogram(icoords, dcoords, ivl, p, n, mh, orientation, no_labels, color_list, leaf_font_size, leaf_rotation, contraction_marks, ax, above_threshold_color)
#    1998             ax.set_xticklabels([])
#    1999         else:
# -> 2000             ax.set_xticks(iv_ticks)
#    2001
#    2002             if orientation == 'top':
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in set_xticks(self, ticks, minor)
#    3335             Default is ``False``.
#    3336         """
# -> 3337         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    3338         self.stale = True
#    3339         return ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in set_ticks(self, ticks, minor)
#    1714         else:
#    1715             self.set_major_locator(mticker.FixedLocator(ticks))
# -> 1716             return self.get_major_ticks(len(ticks))
#    1717
#    1718     def _get_tick_boxes_siblings(self, xdir, renderer):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1393         while len(self.majorTicks) < numticks:
#    1394             # update the new tick label properties from the old
# -> 1395             tick = self._get_tick(major=True)
#    1396             self.majorTicks.append(tick)
#    1397             if self._gridOnMajor:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1816         else:
#    1817             tick_kw = self._minor_tick_kw
# -> 1818         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1819
#    1820     def _get_label(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     172         self.apply_tickdir(tickdir)
#     173
# --> 174         self.tick1line = self._get_tick1line()
#     175         self.tick2line = self._get_tick2line()
#     176         self.gridline = self._get_gridline()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     470                           markeredgewidth=self._width, zorder=self._zorder)
#     471         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
# --> 472         self._set_artist_props(l)
#     473         return l
#     474
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _set_artist_props(self, a)
#     334
#     335     def _set_artist_props(self, a):
# --> 336         a.set_figure(self.figure)
#     337
#     338     def get_view_interval(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in set_figure(self, fig)
#     647         if self.figure and self.figure is not self:
#     648             self.pchanged()
# --> 649         self.stale = True
#     650
#     651     def set_clip_box(self, clipbox):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in stale(self, val)
#     233             return
#     234
# --> 235         if val and self.stale_callback is not None:
#     236             self.stale_callback(self, val)
#     237
#
# KeyboardInterrupt:

# %% [markdown]
# ### AgglomerativeClustering using sklearn

# %%
# Fitting Hierarchical Clustering to the dataset
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = K, affinity = 'euclidean', linkage = 'single')
clusters = hc.fit_predict(X)

# %%
visualize(X,clusters)

# %%
clusters

# %%
max_sum = 0
for i in range(K):
    clValue,counts = np.unique(dataSet[Class][clusters == i],return_counts=True) 
    pieplotter(clValue, counts)
    print(i,clValue,counts)
    max_sum += max(counts)
purity = max_sum/dataSet.shape[0]
    
purity

# %% [markdown]
# ### Reading the data set

# %%
# Importing the dataset
dataSet = pd.read_csv("./../output_data/q-1-1_b_ReLU.csv")
Class = "xAttack"
X = dataSet.iloc[:,:-1].values

# %%
X

# %% [markdown]
# ### setting parameters

# %%
K = 5

# %%
# dendrogram(X)

# %% [markdown]
# ### AgglomerativeClustering using sklearn

# %%
# Fitting Hierarchical Clustering to the dataset
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = K, affinity = 'euclidean', linkage = 'single')
clusters = hc.fit_predict(X)

# %%
visualize(X,clusters)

# %%
clusters

# %%
max_sum = 0
for i in range(K):
    clValue,counts = np.unique(dataSet[Class][clusters == i],return_counts=True) 
    pieplotter(clValue, counts)
    print(i,clValue,counts)
    max_sum += max(counts)
purity = max_sum/dataSet.shape[0]
    
purity

# %% [markdown]
# ### Reading the data set

# %%
# Importing the dataset
dataSet = pd.read_csv("./../output_data/q-1-1_b_tanh.csv")
Class = "xAttack"
X = dataSet.iloc[:,:-1].values

# %%
X

# %% [markdown]
# ### setting parameters

# %%
K = 5

# %%
# dendrogram(X)

# %% [markdown]
# ### AgglomerativeClustering using sklearn

# %%
# Fitting Hierarchical Clustering to the dataset
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = K, affinity = 'euclidean', linkage = 'single')
clusters = hc.fit_predict(X)

# %%
visualize(X,clusters)

# %%
clusters

# %%
max_sum = 0
for i in range(K):
    clValue,counts = np.unique(dataSet[Class][clusters == i],return_counts=True) 
    pieplotter(clValue, counts)
    print(i,clValue,counts)
    max_sum += max(counts)
purity = max_sum/dataSet.shape[0]
    
purity
