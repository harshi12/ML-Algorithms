# %% [markdown]
# # Question 3

# %% [markdown]
# ## import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

eps = np.finfo(float).eps

# %% [markdown]
# ## Utility Functions

# %% [markdown]
# Line Plotter

# %%
def plotter(label_x, label_y, title, x_axis, y_axis, mark='', colr = 'blue'):
    plt.figure(num=None, figsize=(6, 4), dpi=175, facecolor='w', edgecolor='k')
    # plotting the points  
    plt.plot(x_axis, y_axis, marker = mark, color = colr, label = 'Error rate') 
    # naming the x axis 
    plt.xlabel(label_x) 
    # naming the y axis 
    plt.ylabel(label_y) 
    # giving a title to my graph 
    plt.title(title) 
    plt.grid(True)
    # function to show the plot 
    plt.show()

# %% [markdown]
# Scatter Plotter

# %%
def scatterplot(label_x, label_y, title, x_axis, y_axis, mark='.', colr = 'red'):
    plt.figure(num=None, figsize=(6, 4), dpi=175, facecolor='w', edgecolor='k')
    # plotting the y = 0 line  
    plt.axhline(0, color='black')
    # plotting points as a scatter plot 
    plt.scatter(x_axis, y_axis, label= "stars", color = colr, marker= mark, s=30) 
    # naming the x axis 
    plt.xlabel(label_x) 
    # naming the y axis 
    plt.ylabel(label_y) 
    # giving a title to my graph 
    plt.title(title) 
    plt.grid(True)
    # function to show the plot 
    plt.show()

# %% [markdown]
# Normalising the data set to reduce range of values

# %%
def normalize(randomDataSet, columns):
    for attr in columns[:-1]:
        randomDataSet[attr] = (randomDataSet[attr] - randomDataSet[attr].min())/(randomDataSet[attr].max() - randomDataSet[attr].min())
    # randomDataSet = (randomDataSet - randomDataSet.mean())/randomDataSet.std()
    # randomDataSet.head()

# %% [markdown]
# Hypothesis function that defines equation of line

# %%
def hypothesis_hx(theta, row):
    hx = 0
    n = len(theta)
    for i in range(0, n - 1):
        hx += theta[i]*row[i]
    return hx + theta[n - 1]

# %% [markdown]
# Error between calculated value of hypothesis and actul value of y

# %%
def error(df, theta):
    error_list = []
    for index, row in df.iterrows():
        y = row[Class]
        hx = hypothesis_hx(theta, row)
        error_list.append(hx - y)
    return error_list

# %% [markdown]
# Cost Function

# %%
def costFunction(df, theta):
    Jtheta = 0
    er = 0
    error_list = error(df, theta)
    m = len(error_list)
    for i in range(0, m):
        er += np.square(error_list[i])
    Jtheta = er/(2*m)
    return Jtheta , error_list

# %% [markdown]
# Derivative function to calculate derivative of cost function

# %%
def Derivative(df, error_list, theta,j):
    m = len(error_list)
    n = len(theta)
    sum_error = 0
    for i in range(0, m):
        if j == n - 1:
            sum_error += error_list[i]
        else:
            sum_error += error_list[i]*df.iloc[i][j]
    return sum_error/(m)

# %% [markdown]
# Gradient Decent Function

# %%
def gradientDecent(df, theta, error_list, lamda):
    n = len(theta)
    for j in range(0, n):
        theta[j] = theta[j]*(1 - lamda*alpha/len(error_list)) - alpha*Derivative(df, error_list, theta, j)
    return theta

# %% [markdown]
# Model Fitting Function

# %%
# Fitting the Model
def modelFitting(trainingSet,iterate):
    global theta
    iteration_list = []
    cost_list = []
    before = 10
    for i in range(iterate):
        cost , error_list = costFunction(trainingSet, theta)
        theta = gradientDecent(trainingSet, theta, error_list)
        iteration_list.append(i)
        cost_list.append(cost)
        print(i,cost)
    return iteration_list,cost_list

# %% [markdown]
# Valdidation Function for validating the data set for error calculation

# %%
def valdidation(validationSet,theta):
    predicted = []
    actual = []
    for index, row in validationSet.iterrows():
        pred = hypothesis_hx(theta, row)
        ac = row[Class]
        predicted.append(pred)
        actual.append(ac)
        print(pred)
        print(ac)
        print("-----------")
    return predicted , actual

# %% [markdown]
# Mean square error

# %%
# Mean square error
def MSE(predicted , actual):
    return np.mean((np.array(actual) - np.array(predicted))**2)

# %% [markdown]
# Mean absolute error

# %%
# Mean absolute error
def MAE(predicted , actual):
    return np.mean(np.abs((np.array(actual) - np.array(predicted))))

# %% [markdown]
# Mean absolute percentage error function

# %%
# Mean absolute percentage error function
def MAPE(predicted , actual):
    return np.mean(np.abs((np.array(actual) - np.array(predicted))/ np.array(actual))) * 100

# %% [markdown]
# Residual Plotter for verifying correctness of the regression line

# %%
def ResidualPlotter(validationSet, predicted , actual):
    residual = np.array(actual) - np.array(predicted)
    for attr in validationSet:
        scatterplot(attr,'Residual','Residual-vs-' + attr, validationSet[attr],residual)

# %% [markdown]
# ### Reading the Data Set

# %%
randomDataSet = dataSet = pd.read_csv("./../input_data/AdmissionDataset/data.csv")
randomDataSet = dataSet.sample(frac = 1).reset_index(drop = True)
Class = "Chance of Admit "
columns = ['Serial No.' , 'GRE Score' , 'TOEFL Score' , 'University Rating' , 'SOP' , 'LOR' , 'CGPA' , 'Research' , Class]
randomDataSet.columns = columns
columns = columns[1:]
randomDataSet = randomDataSet[columns]

# %% [markdown]
# Plot for Data Analysis and model prediction

# %%
sns.pairplot(dataSet)

# %% [markdown]
# Heat map for corelating the attributes

# %%
sns.heatmap(dataSet.corr(),linewidth = 0.2, vmax=1.0, square=True, linecolor='red',annot=True)

# %% [markdown]
# ### Normalize Data Set

# %%
normalize(randomDataSet, columns)

# %% [markdown]
# ### Data Set spliting

# %%
trainingSet, validationSet = np.split(randomDataSet, [int(0.8*len(randomDataSet))])

# %% [markdown]
# ### Setting parameters for our model

# %%
alpha = 0.01
iterate = 1000
theta = np.zeros([trainingSet.shape[1]])

# %% [markdown]
# ### Training the Model

# %%
iteration_list,cost_list = modelFitting(trainingSet,iterate)
# Out:
# 0 0.26688208333333335
# 1 0.24955167992656402
# 2 0.23336931086130872
# 3 0.21825888524649809
# 4 0.20414935557454952
# 5 0.19097438344018625
# 6 0.1786720274157941
# 7 0.16718445161475656
# 8 0.1564576535715421
# 9 0.146441210158211
# 10 0.1370880403418657
# 11 0.12835418366680693
# 12 0.12019859341914564
# 13 0.11258294350070013
# 14 0.10547144810351114
# 15 0.09883069333653556
# 16 0.09262948001231543
# 17 0.08683867685392431
# 18 0.0814310834315267
# 19 0.07638130218365576
# 20 0.0716656189210689
# 21 0.06726189125094305
# 22 0.06314944439644082
# 23 0.059308973921475695
# 24 0.05572245490298966
# 25 0.05237305712339632
# 26 0.049245065884165246
# 27 0.046323808067971955
# 28 0.04359558310153335
# 29 0.0410475984943044
# 30 0.03866790964974393
# 31 0.036445363665958096
# 32 0.034369546861300886
# 33 0.03243073577803812
# 34 0.030619851433544145
# 35 0.028928416603780788
# 36 0.0273485159380768
# 971 0.0024229841511439676
# 972 0.0024223024451231856
# 973 0.002421622171101462
# 974 0.002420943325036889
# 975 0.002420265902900717
# 976 0.002419589900677298
# 977 0.0024189153143640498
# 978 0.0024182421399714087
# 979 0.0024175703735227765
# 980 0.0024169000110544877
# 981 0.002416231048615762
# 982 0.002415563482268646
# 983 0.0024148973080879814
# 984 0.0024142325221613668
# 985 0.0024135691205890903
# 986 0.00241290709948411
# 987 0.0024122464549719896
# 988 0.0024115871831908733
# 989 0.0024109292802914294
# 990 0.002410272742436801
# 991 0.002409617565802584
# 992 0.002408963746576766
# 993 0.0024083112809596906
# 994 0.002407660165164007
# 995 0.0024070103954146366
# 996 0.00240636196794873
# 997 0.002405714879015611
# 998 0.002405069124876755
# 999 0.0024044247018057286

# %% [markdown]
# ### Plotting the Cost vs Iterations

# %%
plotter('Iterations','Cost','Cost-vs-Iterations',iteration_list,cost_list)

# %% [markdown]
# ### Validating the Model

# %%
predicted , actual = valdidation(validationSet,theta)
# Out:
# 0.6571788083468434
# 0.63
# -----------
# 0.5810865061575792
# 0.63
# -----------
# 0.9201940965767714
# 0.91
# -----------
# 0.5800664820691089
# 0.65
# -----------
# 0.7929922982517594
# 0.8
# -----------
# 0.6096656990817562
# 0.71
# -----------
# 0.8038056786323482
# 0.78
# -----------
# 0.7608426217471542
# 0.78
# -----------
# 0.9042986237409893
# 0.88
# -----------
# 0.6237439323932694
# 0.69
# -----------
# 0.7560451278424114
# 0.77
# -----------
# 0.6317461843025534
# 0.67
# -----------
# 0.6436360921515387
# 0.67
# -----------
# 0.8720046651474505
# 0.87
# -----------
# 0.8386958692012694
# 0.79
# -----------
# 0.5829931743662506
# 0.53
# -----------
# 0.8409527176072884
# 0.8
# -----------
# 0.7105454045194739
# 0.74
# -----------
# 0.7675824328063907
# 0.55
# -----------
# 0.6665904398529667
# 0.77
# -----------
# 0.738988121829655
# 0.75
# -----------
# 0.7800026080161875
# 0.84
# -----------
# 0.8509176138329726
# 0.87
# -----------
# 0.75235611509467
# 0.72
# -----------
# 0.7884553353138528
# 0.77
# -----------
# 0.4611325423438538
# 0.58
# -----------
# 0.5997333226578628
# 0.68
# -----------
# 0.7853376463707669
# 0.84
# -----------
# 0.8597361600425859
# 0.9
# -----------
# 0.5613226934306597
# 0.64
# -----------
# 0.729367963214548
# 0.71
# -----------
# 0.6858830020909386
# 0.62
# -----------
# 0.6314658030132145
# 0.49
# -----------
# 0.676103906823111
# 0.72
# -----------
# 0.8157284605269757
# 0.85
# -----------
# 0.8164104249930388
# 0.82
# -----------
# 0.7227683612593554
# 0.79
# -----------
# 0.4542528611756154
# 0.54
# -----------
# 0.7151999466763107
# 0.63
# -----------
# 0.8731392314071791
# 0.88
# -----------
# 0.9511172984542804
# 0.96
# -----------
# 0.8535286017299621
# 0.81
# -----------
# 0.8246656528118324
# 0.86
# -----------
# 0.6312503713702986
# 0.54
# -----------
# 0.5619994769444638
# 0.67
# -----------
# 0.703375049341812
# 0.72
# -----------
# 0.5072773700945717
# 0.38
# -----------
# 0.9364692837399498
# 0.93
# -----------
# 0.4916967371967635
# 0.69
# -----------
# 0.6715670644601569
# 0.65
# -----------
# 0.7350743254058358
# 0.8
# -----------
# 0.6509294261590514
# 0.66
# -----------
# 0.5152037497426909
# 0.45
# -----------
# 0.6836271231144937
# 0.73
# -----------
# 0.77326249549116
# 0.76
# -----------
# 0.9164514726251871
# 0.9
# -----------
# 0.6947683977862935
# 0.78
# -----------
# 0.7181163333343581
# 0.79
# -----------
# 0.9798139701009467
# 0.94
# -----------
# 0.7175490643131772
# 0.73
# -----------
# 0.7351686451185253
# 0.73
# -----------
# 0.5687435514421897
# 0.72
# -----------
# 0.7771009421909985
# 0.79
# -----------
# 0.760322627587992
# 0.78
# -----------
# 0.5577175301302026
# 0.65
# -----------
# 0.9315933961921725
# 0.91
# -----------
# 0.9362106589212869
# 0.97
# -----------
# 0.9705321430920311
# 0.96
# -----------
# 0.568745234450396
# 0.62
# -----------
# 0.48329602570979013
# 0.56
# -----------
# 0.61198495174469
# 0.73
# -----------
# 0.620034504343282
# 0.67
# -----------
# 0.6676026925552483
# 0.69
# -----------
# 0.7829690029789342
# 0.78
# -----------
# 0.7018556445210415
# 0.72
# -----------
# 0.7045939533011929
# 0.56
# -----------
# 0.6599585919445601
# 0.61
# -----------
# 0.6348265162188131
# 0.65
# -----------
# 0.9529839922870937
# 0.92
# -----------
# 0.6674546724949619
# 0.79
# -----------
# 0.690474365485841
# 0.62
# -----------
# 0.8764922439543104
# 0.87
# -----------
# 0.864872476281183
# 0.91
# -----------
# 0.5748519386785809
# 0.44
# -----------
# 0.5573987728587368
# 0.68
# -----------
# 0.8882319979141642
# 0.93
# -----------
# 0.85489378995389
# 0.87
# -----------
# 0.9206119772155621
# 0.92
# -----------
# 0.5997705498482764
# 0.7
# -----------
# 0.797735008414534
# 0.79
# -----------

# %% [markdown]
# ### Mean Square Error

# %%
MSE(predicted , actual)
# Out:
# 0.004805817927102927

# %% [markdown]
# ### Mean Absolute Error

# %%
MAE(predicted , actual)
# Out:
# 0.05240785669709448

# %% [markdown]
# ### Mean Absolute Percentage Error

# %%
MAPE(predicted , actual)
# Out:
# 8.0546967772014

# %% [markdown]
# ### Plotting the Residual

# %%
ResidualPlotter(validationSet, predicted , actual)

# %% [markdown]
# #### TESTING function resturns list of output

# %%
def TESTING_algo(testingSet):
    global theta
    predicted = []
    for index, row in testingSet.iterrows():
        predicted.append(hypothesis_hx(theta, row))
    return predicted

# %% [markdown]
# ### TEST YOUR DATASET HERE....

# %%
def test(arr):
    length = len(arr)
    global columns
    if length == 2:
        testSetPath = arr[1]
        testingData = pd.read_csv(testSetPath)
        res = TESTING_algo(testingData)
        testingData['RESULT'] = res
        testingData.to_csv("./../output_data/q-3_data_output.csv",index = False)
    return testingData

# %%
test(sys.argv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-2365bbc53d88> in <module>
# ----> 1 test(sys.argv)
#
# NameError: name 'sys' is not defined

# %% [markdown]
# ### Observations
# #### 1) The error value ( which is calculated as the cost function in the code), becomes constant after 800 iterations.
# #### 2) Since the range of output label is very small, it makes the mean square error even smaller which is why the mean absolute error is greater than MSE.
# #### 3) The CGPA column  gives the best resdiual error distribution.
