# %% [markdown]
# # Question 1-2

# %% [markdown]
# ## Importing libraries

# %%
from copy import deepcopy
import numpy as np
import pandas as pd
import math as mt
import sys
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

eps = np.finfo(float).eps

# %% [markdown]
# ### Reading the data set

# %%
dataSet = pd.read_csv("./../input_data/q-1-1_output.csv")
Class = "xAttack"
columns = list(dataSet.columns)
X = dataSet[columns[:-1]].values
# X
Y = dataSet[Class]

# %% [markdown]
# ### setting parameters

# %%
K = 5
n = X.shape[0]
c = X.shape[1]

# %% [markdown]
# ### Random initial position for K clusters centers

# %%
mean = np.mean(X, axis = 0)
std = np.std(X, axis = 0)
centroids = np.random.randn(K,c)*std + mean
centroids
# Out:
# array([[-0.15364896, -0.21284967,  0.77142063,  1.90753896,  0.94598787,
#          0.10667134, -0.73958777, -0.00866569, -1.46084679, -0.37831243,
#         -1.0153303 , -0.30641526, -0.16609575, -1.93479009],
#        [ 1.69535898, -2.05730754,  3.28495304, -0.12872137,  0.96390879,
#          2.5157274 , -1.95700469,  0.69537637, -0.86073338,  0.72339144,
#         -0.85863953, -0.65456159,  0.26203788,  0.34413988],
#        [-0.94843961,  0.56539732, -0.19707937,  0.10205362,  1.34878935,
#         -0.37514154, -2.37060198, -0.8115987 , -0.11522   ,  0.20841597,
#         -0.1002615 ,  0.46918646, -1.0618369 ,  0.14301453],
#        [-1.95316688, -1.78893692,  1.25918653,  0.72858304, -1.40500539,
#         -0.09980604,  1.26805967,  0.84793324,  1.65824774, -1.65676786,
#         -0.04522739,  0.7443779 , -0.821259  ,  0.95074015],
#        [-0.74389709,  3.61868902, -0.39280101,  0.39218327, -0.56780056,
#          0.64355177,  0.30468713,  0.21647584, -0.82835475, -0.89578366,
#         -2.77370244, -0.67400443,  0.40236685,  0.45981807]])

# %% [markdown]
# ### K-Means Alogo

# %%
centers_new = deepcopy(centroids) # Store new centers

clusters = np.zeros(n)
distances = np.zeros((n,K))
error = 1
itr = 0
# When, after an update, the estimate of that center stays the same, exit loop
while error != 0:
    itr += 1
    print("Iteration: ", itr)
    # Measure the distance to every center
    for i in range(K):
        distances[:,i] = np.linalg.norm(X - centers_new[i], axis=1)
    # Assign all training data to closest center
    clusters = np.argmin(distances, axis = 1)
    centers_old = deepcopy(centers_new)
    # Calculate mean for every cluster and update the center
    for i in range(K):
        centers_new[i] = np.mean(X[clusters == i], axis=0)
    error = np.linalg.norm(centers_new - centers_old)
centers_new
# Out:
# Iteration:  1
# Iteration:  2
# Iteration:  3
# Iteration:  4
# Iteration:  5
# Iteration:  6
# Iteration:  7
# Iteration:  8
# Iteration:  9
# Iteration:  10
# Iteration:  11
# array([[ 3.76450162e+00,  1.22641537e+00, -1.31760394e-02,
#         -2.73006592e-01,  4.74901879e-03, -2.59154936e-01,
#         -1.56843944e-01, -5.13369832e-02,  1.54584295e-02,
#          1.43940815e-03,  5.14446792e-02, -3.31575605e-02,
#         -7.09095778e-02, -4.42551125e-02],
#        [ 1.22407654e+00, -5.51542197e+00, -1.22665143e-01,
#         -7.02627205e-01,  1.13859046e+00,  2.53018303e+00,
#          1.04460587e+00, -3.62956338e-01, -2.09540889e-01,
#          6.66652196e-02, -4.87841825e-02,  6.01537181e-02,
#         -4.74848033e-01, -8.55180172e-01],
#        [-1.73848126e+00,  6.24557959e-01,  4.85906963e-02,
#          5.24279786e-01, -1.17617366e-01,  3.50609257e-01,
#          6.94922554e-02, -1.08476976e-02, -1.16697055e-02,
#         -1.87998005e-02,  5.66290669e-03, -3.65929552e-02,
#         -1.03285269e-01,  1.42003709e-01],
#        [ 9.34411423e-02, -5.21919567e+00,  2.28442672e-01,
#          4.60990859e-01, -7.44391481e-01, -1.67864655e+00,
#         -6.39843916e-01,  1.47430214e-01,  1.04610877e-01,
#         -4.91191531e-02,  4.98267845e-02, -3.31666516e-02,
#          1.49422490e-01,  3.76495070e-01],
#        [-2.68995244e+00,  5.50159537e-01, -4.65843532e-01,
#         -2.64603457e+00,  9.50652538e-01, -9.92904875e-01,
#          2.13229065e-01,  3.01867107e-01,  2.64204791e-02,
#          1.37619247e-01, -2.50765530e-01,  3.66858782e-01,
#          1.05484909e+00, -7.20432113e-01]])

# %% [markdown]
# ### Piechart plotter

# %%
def pieplotter(labels, sizes):
    plt.figure(num=None, figsize=(6, 4), dpi=150, facecolor='c', edgecolor='k')
    
    colors = ['lightcoral','gold', 'yellowgreen','lightskyblue', 'red','blue']
    patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
    plt.legend( loc = 'best', labels=['%s, %1.1f %%' % (l, 100*s/sum(sizes)) for l, s in zip(labels, sizes)])
    
    plt.axis('equal')
    plt.tight_layout()
    plt.show()

# %%
max_sum = 0
for i in range(K):
    clValue,counts = np.unique(dataSet[Class][clusters == i],return_counts=True)  
    pieplotter(clValue, counts)
    print(i,clValue,counts)
    max_sum += max(counts)
purity = max_sum/dataSet.shape[0]
    
purity
# Out:
# 0 ['dos' 'normal' 'probe'] [6804   32   64]
# 1 ['dos' 'normal' 'probe'] [ 11 232 879]
# 2 ['dos' 'normal' 'probe' 'r2l' 'u2r'] [  909 11537   284   136    10]
# 3 ['dos' 'normal' 'probe' 'r2l'] [1366  537  266   10]
# 4 ['dos' 'normal' 'probe' 'r2l'] [  24 1026  820   51]
# 0.8645491639331147
