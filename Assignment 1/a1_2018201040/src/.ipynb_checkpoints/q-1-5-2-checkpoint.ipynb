# %% [markdown]
# # Part-5 section-2

# %% [markdown]
# ### Plot a graph of training and validation error with respect to depth of your decision tree. Also plot the training and validation error with respect to number of nodes in the decision tree.

# %%
import numpy as np
import pandas as pd
import pprint
import sys

eps = np.finfo(float).eps
true_positive = 0
true_negative = 0
false_positive = 0
false_negative = 0
MAX_HEIGHT = 0
from numpy import log2 as log
targetattr = "left"
dataSet = pd.read_csv("./../input_data/train.csv")
numerical = ['satisfaction_level' , 'last_evaluation' , 'number_project' , 'average_montly_hours' , 'time_spend_company']
catagorical = ['Work_accident' , 'promotion_last_5years' , 'sales' , 'salary']
trainingSet , validationSet = np.split(dataSet,[int(0.8*len(dataSet))])

# %% [markdown]
# #### maxInfoGainNodeSplit function decides which attribute is selected as node and give the binary splite point in case of numerical attribute

# %%
def maxInfoGainNodeSplit(df):
    attributes = list(df)
    maxGain = 0.0
    gain = 0.0
    split = 0
    temp = 0.0
    entropybefore = entropy(df)
    for attr in attributes:
        if attr != targetattr:
            if attr in catagorical:
                gain = entropybefore - I(df,attr)
                if maxGain < gain:
                    maxGain = gain
                    node = attr
                    split = 0
            else:
                temp, ImpurityNum = InumMin(df,attr)
                gain = entropybefore - ImpurityNum
                if maxGain < gain:
                    maxGain = gain
                    node = attr
                    split = temp
    if maxGain == 0.0:
        return None , split
    else:
        return node , split

# %% [markdown]
# #### entropy function for entropy before spliting

# %%
def entropy(df):
    entropy = 0
    uniqueSet = df[targetattr].unique()
    for elem in uniqueSet:
        fraction = df[targetattr].value_counts()[elem]/float(len(df)+ eps)
        entropy += -fraction*np.log2(fraction + eps)
    return entropy

# %% [markdown]
# #### entropy_attr function for entropy after spliting

# %%
def entropy_attr(num_of_ones , total):
    fraction1 = num_of_ones/(total + eps)
    fraction2 = (total - num_of_ones)/(total + eps)
    entropy = -fraction1*np.log2(fraction1 + eps) - fraction2*np.log2(fraction2 + eps)
    return entropy

# %% [markdown]
# #### InumMin function to calculate minimun impurity for weighted entropy in numerical attribute

# %%
def InumMin(df , attribute):
    target_variables = df[targetattr].unique()  #This gives all 'Yes' and 'No'
#     print("TARGET VARS : ",target_variables[0])
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    
    variables.sort()
    
    split = 0
    minInum = sys.float_info.max
    total_ones = df[targetattr].value_counts()[target_variables[0]]
    arr = df[[attribute, targetattr]].values
    arr = arr[np.argsort(arr[:, 0])]

    nRows = arr.shape[0]

    num_of_ones = 0
    i = 0
    for variable in variables:
        impurity = 0.0
        while (i < nRows and arr[i][0] == variable) :
            if arr[i][1] == target_variables[0]:
                num_of_ones += 1
            i += 1
        num_left = i
        fraction_left = num_left/(nRows + eps)
        if num_left == 0:
            impurity += 0.0
        else:
            impurity += fraction_left*entropy_attr(num_of_ones , num_left) 
            
        num_right = nRows - num_left
        fraction_right = num_right/(nRows + eps)
        if num_right == 0:
            impurity += 0.0
        else:
            impurity += fraction_right*entropy_attr(total_ones - num_of_ones , num_right) 
        
        if minInum > impurity:
            minInum = impurity
            split = variable
        
    return split , minInum

# %% [markdown]
# #### Impurity function to calculate impurity for weighted entropy

# %%
def I(df , attribute):
    target_variables = df[targetattr].unique()  #This gives all 'Yes' and 'No'
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    den = len(df[attribute])
    impurity = 0
    for variable in variables:
        num = len(df[attribute][df[attribute] == variable])
        fraction = num/(den + eps)
        if num == 0:
            impurity += 0.0
        else:
            impurity += fraction*entropy(df[df[attribute] == variable]) 
    return impurity

# %% [markdown]
# #### get_subtableCat to filter data frame that has catagorical attribute

# %%
def get_subtableCat(df, node,value):
    return df[df[node] == value].reset_index(drop=True)

# %% [markdown]
# #### get_subtableCat to filter data frame that has numerical attribute

# %%
def get_subtableNum(df, node, value):
    return df[df[node] <= value].reset_index(drop=True) , df[df[node] > value].reset_index(drop=True)

# %% [markdown]
# #### Tree Builder Function

# %%
def treeBuilder(df, depth ,tree=None):     
    #Here we build our decision tree   
    #Get attribute with maximum information gain
    node, split = maxInfoGainNodeSplit(df)
    clValue,counts = np.unique(df[targetattr],return_counts=True)  
    if node is None:
        return clValue[np.argmax(counts)]

    print (node)
    
    #Create an empty dictionary to create tree    
    if tree is None:                    
        tree={}
        tree[node] = {}
        tree['DEPTH'] = depth
        tree['CUR_VALUE'] = clValue[np.argmax(counts)]
        tree['DF_SIZE'] = len(df)
    if node in catagorical:
        #Get distinct value of that attribute e.g Salary is node and Low,Med and High are values
        attValue = np.unique(df[node])


       #We make loop to construct a tree by calling this function recursively. 
        #In this we check if the subset is pure and stops if it is pure. 

        for value in attValue:
            subtable = get_subtableCat(df,node,value)
            clValue,counts = np.unique(subtable[targetattr],return_counts=True)                        

            if len(counts)==1:#Checking purity of subset
                tree[node][value] = clValue[0]
            else:        
                tree[node][value] = treeBuilder(subtable , depth + 1) #Calling the function recursively 
                
    elif node in numerical:
        left_subtable , right_subtable = get_subtableNum(df,node,split)
        
        clValue,counts = np.unique(left_subtable[targetattr],return_counts=True)                      
        
        if len(counts)==1:#Checking purity of subset
            tree[node][split] = clValue[0]
        else:        
            tree[node][split] = treeBuilder(left_subtable , depth + 1) #Calling the function recursively 
            
        clValue,counts = np.unique(right_subtable[targetattr],return_counts=True)                        
        
        if len(counts)==1:#Checking purity of subset
            tree[node][split + 0.00002] = clValue[0]
        else:        
            tree[node][split + 0.00002] = treeBuilder(right_subtable , depth + 1) #Calling the function recursively 
            
    return tree

# %% [markdown]
# #### Run the code to build the tree

# %%
tree = treeBuilder(trainingSet,0)
pprint.pprint(tree)
# Out:
# {'CUR_VALUE': 0,
#  'DEPTH': 0,
#  'satisfaction_level': {0.46: {'CUR_VALUE': 1,
#                                'DEPTH': 1,
#                                'satisfaction_level': {0.11: 1,
#                                                       0.11002: {'CUR_VALUE': 0,
#                                                                 'DEPTH': 2,
#                                                                 'number_project': {2: {'CUR_VALUE': 1,
#                                                                                        'DEPTH': 3,
#                                                                                        'last_evaluation': {0.57: {'CUR_VALUE': 1,
#                                                                                                                   'DEPTH': 4,
#                                                                                                                   'last_evaluation': {0.44: 0,
#                                                                                                                                       0.44002: {'CUR_VALUE': 1,
#                                                                                                                                                 'DEPTH': 5,
#                                                                                                                                                 'average_montly_hours': {161: {'CUR_VALUE': 1,
#                                                                                                                                                                                'DEPTH': 6,
#                                                                                                                                                                                'satisfaction_level': {0.31: 0,
#                                                                                                                                                                                                       0.31002: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                 'DEPTH': 7,
#                                                                                                                                                                                                                 'average_montly_hours': {125: 0,
#                                                                                                                                                                                                                                          125.00002: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                      'DEPTH': 8,
#                                                                                                                                                                                                                                                      'salary': {'high': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                          'DEPTH': 9,
#                                                                                                                                                                                                                                                                          'sales': {'IT': 0,
#                                                                                                                                                                                                                                                                                    'RandD': 1,
#                                                                                                                                                                                                                                                                                    'accounting': 1,
#                                                                                                                                                                                                                                                                                    'hr': 1,
#                                                                                                                                                                                                                                                                                    'marketing': 1,
#                                                                                                                                                                                                                                                                                    'product_mng': 1,
#                                                                                                                                                                                                                                                                                    'sales': 1,
#                                                                                                                                                                                                                                                                                    'support': 1,
#                                                                                                                                                                                                                                                                                    'technical': 1}},
#                                                                                                                                                                                                                                                                 'low': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                         'DEPTH': 9,
#                                                                                                                                                                                                                                                                         'sales': {'IT': 1,
#                                                                                                                                                                                                                                                                                   'RandD': 1,
#                                                                                                                                                                                                                                                                                   'accounting': 1,
#                                                                                                                                                                                                                                                                                   'hr': 1,
#                                                                                                                                                                                                                                                                                   'management': 1,
#                                                                                                                                                                                                                                                                                   'marketing': 1,
#                                                                                                                                                                                                                                                                                   'product_mng': 1,
#                                                                                                                                                                                                                                                                                   'sales': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                             'DEPTH': 10,
#                                                                                                                                                                                                                                                                                             'average_montly_hours': {150: 1,
#                                                                                                                                                                                                                                                                                                                      150.00002: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                  'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                                  'average_montly_hours': {151: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                 'DEPTH': 12,
#                                                                                                                                                                                                                                                                                                                                                                 'satisfaction_level': {0.41: 1,
#                                                                                                                                                                                                                                                                                                                                                                                        0.41002: 0}},
#                                                                                                                                                                                                                                                                                                                                                           151.00002: 1}}}},
#                                                                                                                                                                                                                                                                                   'support': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                               'DEPTH': 10,
#                                                                                                                                                                                                                                                                                               'average_montly_hours': {132: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                              'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                              'satisfaction_level': {0.39: 0,
#                                                                                                                                                                                                                                                                                                                                                     0.39002000000000003: 1}},
#                                                                                                                                                                                                                                                                                                                        132.00002: 1}},
#                                                                                                                                                                                                                                                                                   'technical': 1}},
#                                                                                                                                                                                                                                                                 'medium': 1}}}}}},
#                                                                                                                                                                          161.00002: {'CUR_VALUE': 0,
#                                                                                                                                                                                      'DEPTH': 6,
#                                                                                                                                                                                      'satisfaction_level': {0.41: 0,
#                                                                                                                                                                                                             0.41002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                       'DEPTH': 7,
#                                                                                                                                                                                                                       'average_montly_hours': {219: 0,
#                                                                                                                                                                                                                                                219.00002: 1}}}}}}}},
#                                                                                                            0.57002: {'CUR_VALUE': 0,
#                                                                                                                      'DEPTH': 4,
#                                                                                                                      'last_evaluation': {0.77: 0,
#                                                                                                                                          0.77002: {'CUR_VALUE': 0,
#                                                                                                                                                    'DEPTH': 5,
#                                                                                                                                                    'last_evaluation': {0.78: 1,
#                                                                                                                                                                        0.78002: {'CUR_VALUE': 0,
#                                                                                                                                                                                  'DEPTH': 6,
#                                                                                                                                                                                  'satisfaction_level': {0.43: 0,
#                                                                                                                                                                                                         0.43002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                   'DEPTH': 7,
#                                                                                                                                                                                                                   'last_evaluation': {0.82: 0,
#                                                                                                                                                                                                                                       0.82002: 1}}}}}}}}}},
#                                                                                    2.00002: {'CUR_VALUE': 0,
#                                                                                              'DEPTH': 3,
#                                                                                              'number_project': {6: {'CUR_VALUE': 0,
#                                                                                                                     'DEPTH': 4,
#                                                                                                                     'average_montly_hours': {287: {'CUR_VALUE': 0,
#                                                                                                                                                    'DEPTH': 5,
#                                                                                                                                                    'sales': {'IT': {'CUR_VALUE': 0,
#                                                                                                                                                                     'DEPTH': 6,
#                                                                                                                                                                     'satisfaction_level': {0.14: {'CUR_VALUE': 0,
#                                                                                                                                                                                                   'DEPTH': 7,
#                                                                                                                                                                                                   'last_evaluation': {0.55: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                              'DEPTH': 8,
#                                                                                                                                                                                                                              'satisfaction_level': {0.12: 0,
#                                                                                                                                                                                                                                                     0.12002: 1}},
#                                                                                                                                                                                                                       0.5500200000000001: 0}},
#                                                                                                                                                                                            0.14002: 0}},
#                                                                                                                                                              'RandD': {'CUR_VALUE': 0,
#                                                                                                                                                                        'DEPTH': 6,
#                                                                                                                                                                        'last_evaluation': {0.99: {'CUR_VALUE': 0,
#                                                                                                                                                                                                   'DEPTH': 7,
#                                                                                                                                                                                                   'last_evaluation': {0.87: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                              'DEPTH': 8,
#                                                                                                                                                                                                                              'satisfaction_level': {0.14: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                            'DEPTH': 9,
#                                                                                                                                                                                                                                                            'satisfaction_level': {0.13: 0,
#                                                                                                                                                                                                                                                                                   0.13002: 1}},
#                                                                                                                                                                                                                                                     0.14002: 0}},
#                                                                                                                                                                                                                       0.87002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                 'DEPTH': 8,
#                                                                                                                                                                                                                                 'satisfaction_level': {0.29: 0,
#                                                                                                                                                                                                                                                        0.29002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                  'DEPTH': 9,
#                                                                                                                                                                                                                                                                  'number_project': {3: 0,
#                                                                                                                                                                                                                                                                                     3.00002: 1}}}}}},
#                                                                                                                                                                                            0.99002: 1}},
#                                                                                                                                                              'accounting': {'CUR_VALUE': 0,
#                                                                                                                                                                             'DEPTH': 6,
#                                                                                                                                                                             'average_montly_hours': {186: 0,
#                                                                                                                                                                                                      186.00002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                  'DEPTH': 7,
#                                                                                                                                                                                                                  'last_evaluation': {0.95: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                             'DEPTH': 8,
#                                                                                                                                                                                                                                             'last_evaluation': {0.65: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                        'DEPTH': 9,
#                                                                                                                                                                                                                                                                        'salary': {'high': 0,
#                                                                                                                                                                                                                                                                                   'low': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                           'DEPTH': 10,
#                                                                                                                                                                                                                                                                                           'satisfaction_level': {0.24: 0,
#                                                                                                                                                                                                                                                                                                                  0.24001999999999998: 1}},
#                                                                                                                                                                                                                                                                                   'medium': {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                              'DEPTH': 10,
#                                                                                                                                                                                                                                                                                              'last_evaluation': {0.54: 0,
#                                                                                                                                                                                                                                                                                                                  0.5400200000000001: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                       'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                                       'satisfaction_level': {0.31: 1,
#                                                                                                                                                                                                                                                                                                                                                              0.31002: 0}}}}}},
#                                                                                                                                                                                                                                                                 0.65002: 0}},
#                                                                                                                                                                                                                                      0.95002: 1}}}},
#                                                                                                                                                              'hr': 0,
#                                                                                                                                                              'management': {'CUR_VALUE': 0,
#                                                                                                                                                                             'DEPTH': 6,
#                                                                                                                                                                             'satisfaction_level': {0.39: 0,
#                                                                                                                                                                                                    0.39002000000000003: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                          'DEPTH': 7,
#                                                                                                                                                                                                                          'satisfaction_level': {0.42: 1,
#                                                                                                                                                                                                                                                 0.42002: 0}}}},
#                                                                                                                                                              'marketing': 0,
#                                                                                                                                                              'product_mng': {'CUR_VALUE': 0,
#                                                                                                                                                                              'DEPTH': 6,
#                                                                                                                                                                              'number_project': {5: 0,
#                                                                                                                                                                                                 5.00002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                           'DEPTH': 7,
#                                                                                                                                                                                                           'satisfaction_level': {0.28: 0,
#                                                                                                                                                                                                                                  0.28002000000000005: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                        'DEPTH': 8,
#                                                                                                                                                                                                                                                        'satisfaction_level': {0.31: 1,
#                                                                                                                                                                                                                                                                               0.31002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                         'DEPTH': 9,
#                                                                                                                                                                                                                                                                                         'satisfaction_level': {0.32: 0,
#                                                                                                                                                                                                                                                                                                                0.32002: 1}}}}}}}},
#                                                                                                                                                              'sales': {'CUR_VALUE': 0,
#                                                                                                                                                                        'DEPTH': 6,
#                                                                                                                                                                        'time_spend_company': {5: {'CUR_VALUE': 0,
#                                                                                                                                                                                                   'DEPTH': 7,
#                                                                                                                                                                                                   'last_evaluation': {0.53: 0,
#                                                                                                                                                                                                                       0.53002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                 'DEPTH': 8,
#                                                                                                                                                                                                                                 'satisfaction_level': {0.3: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                              'DEPTH': 9,
#                                                                                                                                                                                                                                                              'average_montly_hours': {231: 0,
#                                                                                                                                                                                                                                                                                       231.00002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                                   'DEPTH': 10,
#                                                                                                                                                                                                                                                                                                   'satisfaction_level': {0.2: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                                                                'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                                'satisfaction_level': {0.13: 0,
#                                                                                                                                                                                                                                                                                                                                                       0.13002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                                                                                                 'DEPTH': 12,
#                                                                                                                                                                                                                                                                                                                                                                 'time_spend_company': {3: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                                            'DEPTH': 13,
#                                                                                                                                                                                                                                                                                                                                                                                            'last_evaluation': {0.57: 0,
#                                                                                                                                                                                                                                                                                                                                                                                                                0.57002: 1}},
#                                                                                                                                                                                                                                                                                                                                                                                        3.00002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                                                                                                                                  'DEPTH': 13,
#                                                                                                                                                                                                                                                                                                                                                                                                  'average_montly_hours': {275: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                                                                                                                                                                 'DEPTH': 14,
#                                                                                                                                                                                                                                                                                                                                                                                                                                 'last_evaluation': {0.55: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                            'DEPTH': 15,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                            'satisfaction_level': {0.14: 0,
# ...
#                                                                                                                                                                                                                                                                                                                                                     'RandD': 1,
#                                                                                                                                                                                                                                                                                                                                                     'accounting': 1,
#                                                                                                                                                                                                                                                                                                                                                     'hr': 1,
#                                                                                                                                                                                                                                                                                                                                                     'management': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                    'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                                                                    'satisfaction_level': {0.88: 1,
#                                                                                                                                                                                                                                                                                                                                                                                           0.88002: 0}},
#                                                                                                                                                                                                                                                                                                                                                     'marketing': 1,
#                                                                                                                                                                                                                                                                                                                                                     'product_mng': 1,
#                                                                                                                                                                                                                                                                                                                                                     'sales': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                               'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                                                               'last_evaluation': {0.87: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                                          'DEPTH': 12,
#                                                                                                                                                                                                                                                                                                                                                                                          'number_project': {4: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                                                                                                                                                 'DEPTH': 13,
#                                                                                                                                                                                                                                                                                                                                                                                                                 'satisfaction_level': {0.78: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                        0.78002: 0}},
#                                                                                                                                                                                                                                                                                                                                                                                                             4.00002: 1}},
#                                                                                                                                                                                                                                                                                                                                                                                   0.87002: 1}},
#                                                                                                                                                                                                                                                                                                                                                     'support': 1,
#                                                                                                                                                                                                                                                                                                                                                     'technical': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                   'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                                                                   'salary': {'high': 1,
#                                                                                                                                                                                                                                                                                                                                                                              'low': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                                      'DEPTH': 12,
#                                                                                                                                                                                                                                                                                                                                                                                      'last_evaluation': {0.85: 0,
#                                                                                                                                                                                                                                                                                                                                                                                                          0.85002: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                    'DEPTH': 13,
#                                                                                                                                                                                                                                                                                                                                                                                                                    'average_montly_hours': {235: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                             235.00002: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                         'DEPTH': 14,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                         'satisfaction_level': {0.81: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.8100200000000001: 0}}}}}},
#                                                                                                                                                                                                                                                                                                                                                                              'medium': 1}}}},
#                                                                                                                                                                                                                                                                                                                                    0.91002: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                              'DEPTH': 10,
#                                                                                                                                                                                                                                                                                                                                              'last_evaluation': {0.87: 1,
#                                                                                                                                                                                                                                                                                                                                                                  0.87002: 0}}}},
#                                                                                                                                                                                                                                                                                                       238.00002: 1}},
#                                                                                                                                                                                                                                                                          5.00002: 0}},
#                                                                                                                                                                                                                                                   6.00002: 0}}}}}}}}}}}}}}

# %% [markdown]
# #### predict function predicts the value of class attribute for a given row of input and tree

# %%
def predict(tree , row, df_size = None):
    #This function is used to predict for any input variable 
    
    #Recursively we go through the tree that we built earlier
    if tree['DF_SIZE'] <= df_size:
        return tree['CUR_VALUE']
    prediction = 0
    for nodes in tree.keys():  
        if nodes == 'DEPTH' or nodes == 'CUR_VALUE' or nodes == 'DF_SIZE':
            continue
        value = row[nodes]
        if nodes in catagorical:
            if value in list((tree[nodes]).keys()):
                tree = tree[nodes][value]
            else:
                zeros = 0
                ones = 0
                for i in tree[nodes].keys():
                    if tree[nodes][i] == 0:
                        zeros += 1
                    elif tree[nodes][i] == 1:
                        ones += 1
                if zeros > ones:
                    return 0
                else:
                    return 1
        else:
            binaryValue = list(tree[nodes].keys())
            if value <= binaryValue[0]:
                tree = tree[nodes][binaryValue[0]]
            else:
                tree = tree[nodes][binaryValue[1]]
        if type(tree) is dict:
            prediction = predict(tree , row, df_size)
        else:
            prediction = tree
            break;   
            
    return prediction

# %% [markdown]
# #### validate function validates the given Data Frame

# %%
def validate(tree, df):
    ACC = []
    for i in range(0,9200,100):
        correct = 0
        wrong = 0
        for index, row in df.iterrows():
            if predict(tree, row, i) == row[targetattr]:
                correct += 1
            else:
                wrong += 1
        ACC.append(100.0*correct/(correct + wrong + eps))
    print(ACC)
    return ACC

# %% [markdown]
# #### Plotting the Accuracy-vs-Nodes graph

# %%
import matplotlib.pyplot as plt
ACC_validSet = validate(tree , validationSet)
ACC_trainSet = validate(tree , trainingSet)
 
NODES = []
for i in  range(0 , len(ACC_validSet)):
    NODES.append(i*100)
#     print("ValidationSet Accuracy at depth: "+ str(i*100) +" is "+ str(ACC_validSet[i]) + "%")
#     print("TrainingSet Accuracy at depth: "+ str(i*100) +" is "+ str(ACC_trainSet[i]) + "%")
    
plt.figure(num=None, figsize=(8, 6), dpi=200, facecolor='w', edgecolor='k')
# plotting the points  
plt.plot(NODES, ACC_validSet, label = "Validation Set") 
plt.plot(NODES, ACC_trainSet, label = "Training Set")  
# naming the x axis 
plt.xlabel('Number of Nodes') 
# naming the y axis 
plt.ylabel('Accuracy') 
  
# giving a title to my graph 
plt.title('Accuracy-vs-Nodes') 
plt.grid(True)
plt.legend() 

plt.savefig('Plot/5.2 Accuracy-vs-Nodes.png')

# function to show the plot 
plt.show()


ACC_validSet[:] = [100 - x for x in ACC_validSet]
ACC_trainSet[:] = [100 - x for x in ACC_trainSet]

plt.figure(num=None, figsize=(8, 6), dpi=200, facecolor='w', edgecolor='k')
# plotting the points  
plt.plot(NODES, ACC_validSet, label = "Validation Set") 
plt.plot(NODES, ACC_trainSet, label = "Training Set")    
# naming the x axis 
plt.xlabel('Number of Nodes') 
# naming the y axis 
plt.ylabel('Error rate') 
  
# giving a title to my graph 
plt.title('Error rate-vs-Nodes') 
plt.grid(True)
plt.legend() 
  
plt.savefig('Plot/5.2 Error rate-vs-Nodes.png')

# function to show the plot 
plt.show()
# Out:
# [75.75622775800711, 81.67259786476869, 81.36120996441281, 93.72775800711744, 96.26334519572954, 97.06405693950178, 97.2864768683274, 97.68683274021352, 97.86476868327402, 97.86476868327402, 97.77580071174377, 97.90925266903915, 97.8202846975089, 97.73131672597864, 97.73131672597864, 97.77580071174377, 97.77580071174377, 97.77580071174377, 97.77580071174377]
# [76.30700778642937, 82.18020022246941, 82.40266963292547, 94.49388209121246, 96.69632925472747, 97.4638487208009, 98.04226918798665, 98.47608453837597, 98.84315906562847, 99.06562847608454, 99.37708565072303, 99.51056729699667, 99.6329254727475, 99.76640711902114, 99.85539488320356, 99.89988876529478, 99.93325917686317, 99.94438264738598, 99.97775305895439]
# ValidationSet Accuracy at depth: 0 is 75.75622775800711%
# TrainingSet Accuracy at depth: 0 is 76.30700778642937%
# ValidationSet Accuracy at depth: 1 is 81.67259786476869%
# TrainingSet Accuracy at depth: 1 is 82.18020022246941%
# ValidationSet Accuracy at depth: 2 is 81.36120996441281%
# TrainingSet Accuracy at depth: 2 is 82.40266963292547%
# ValidationSet Accuracy at depth: 3 is 93.72775800711744%
# TrainingSet Accuracy at depth: 3 is 94.49388209121246%
# ValidationSet Accuracy at depth: 4 is 96.26334519572954%
# TrainingSet Accuracy at depth: 4 is 96.69632925472747%
# ValidationSet Accuracy at depth: 5 is 97.06405693950178%
# TrainingSet Accuracy at depth: 5 is 97.4638487208009%
# ValidationSet Accuracy at depth: 6 is 97.2864768683274%
# TrainingSet Accuracy at depth: 6 is 98.04226918798665%
# ValidationSet Accuracy at depth: 7 is 97.68683274021352%
# TrainingSet Accuracy at depth: 7 is 98.47608453837597%
# ValidationSet Accuracy at depth: 8 is 97.86476868327402%
# TrainingSet Accuracy at depth: 8 is 98.84315906562847%
# ValidationSet Accuracy at depth: 9 is 97.86476868327402%
# TrainingSet Accuracy at depth: 9 is 99.06562847608454%
# ValidationSet Accuracy at depth: 10 is 97.77580071174377%
# TrainingSet Accuracy at depth: 10 is 99.37708565072303%
# ValidationSet Accuracy at depth: 11 is 97.90925266903915%
# TrainingSet Accuracy at depth: 11 is 99.51056729699667%
# ValidationSet Accuracy at depth: 12 is 97.8202846975089%
# TrainingSet Accuracy at depth: 12 is 99.6329254727475%
# ValidationSet Accuracy at depth: 13 is 97.73131672597864%
# TrainingSet Accuracy at depth: 13 is 99.76640711902114%
# ValidationSet Accuracy at depth: 14 is 97.73131672597864%
# TrainingSet Accuracy at depth: 14 is 99.85539488320356%
# ValidationSet Accuracy at depth: 15 is 97.77580071174377%
# TrainingSet Accuracy at depth: 15 is 99.89988876529478%
# ValidationSet Accuracy at depth: 16 is 97.77580071174377%
# TrainingSet Accuracy at depth: 16 is 99.93325917686317%
# ValidationSet Accuracy at depth: 17 is 97.77580071174377%
# TrainingSet Accuracy at depth: 17 is 99.94438264738598%
# ValidationSet Accuracy at depth: 18 is 97.77580071174377%
# TrainingSet Accuracy at depth: 18 is 99.97775305895439%
