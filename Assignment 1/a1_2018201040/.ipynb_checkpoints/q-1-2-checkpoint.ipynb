# %%
def maxInfoGainNodeSplit(df):
    attributes = list(df)
    maxGain = 0.0
    gain = 0.0
    split = 0
    temp = 0.0
    entropybefore = entropy(df)
    for attr in attributes:
        if attr != targetattr:
            if attr in catagorical:
                gain = entropybefore - I(df,attr)
                if maxGain < gain:
                    maxGain = gain
                    node = attr
                    split = 0
            else:
                temp, ImpurityNum = InumMin(df,attr)
                gain = entropybefore - ImpurityNum
                if maxGain < gain:
                    maxGain = gain
                    node = attr
                    split = temp
    if maxGain == 0.0:
        return None , split
    else:
        return node , split

# %%
def entropy(df):
    entropy = 0
    uniqueSet = df[targetattr].unique()
    for elem in uniqueSet:
        fraction = df[targetattr].value_counts()[elem]/float(len(df)+ eps)
        entropy += -fraction*np.log2(fraction + eps)
    return entropy

# %%
def entropy_attr(num_of_ones , total):
    fraction1 = num_of_ones/(total + eps)
    fraction2 = (total - num_of_ones)/(total + eps)
    entropy = -fraction1*np.log2(fraction1 + eps) - fraction2*np.log2(fraction2 + eps)
    return entropy

# %%
import sys

def InumMin(df , attribute):
    target_variables = df[targetattr].unique()  #This gives all 'Yes' and 'No'
#     print("TARGET VARS : ",target_variables[0])
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    
    variables.sort()
    
    split = 0
    minInum = sys.float_info.max
    total_ones = df[targetattr].value_counts()[target_variables[0]]
    arr = df[[attribute, targetattr]].values
    arr = arr[np.argsort(arr[:, 0])]

    nRows = arr.shape[0]

    num_of_ones = 0
    i = 0
    for variable in variables:
        impurity = 0.0
        while (i < nRows and arr[i][0] == variable) :
            if arr[i][1] == target_variables[0]:
                num_of_ones += 1
            i += 1
        num_left = i
        fraction_left = num_left/(nRows + eps)
        if num_left == 0:
            impurity += 0.0
        else:
            impurity += fraction_left*entropy_attr(num_of_ones , num_left) 
            
        num_right = nRows - num_left
        fraction_right = num_right/(nRows + eps)
        if num_right == 0:
            impurity += 0.0
        else:
            impurity += fraction_right*entropy_attr(total_ones - num_of_ones , num_right) 
        
        if minInum > impurity:
            minInum = impurity
            split = variable
        
    return split , minInum

# %%
def I(df , attribute):
    target_variables = df[targetattr].unique()  #This gives all 'Yes' and 'No'
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    den = len(df[attribute])
    impurity = 0
    for variable in variables:
        num = len(df[attribute][df[attribute] == variable])
        fraction = num/(den + eps)
        if num == 0:
            impurity += 0.0
        else:
            impurity += fraction*entropy(df[df[attribute] == variable]) 
    return impurity

# %%
def get_subtableCat(df, node,value):
    return df[df[node] == value].reset_index(drop=True)

# %%
def get_subtableNum(df, node, value):
    return df[df[node] <= value].reset_index(drop=True) , df[df[node] > value].reset_index(drop=True)

# %%
def treeBuilder(df, tree=None):     
    #Here we build our decision tree   
    #Get attribute with maximum information gain
    node, split = maxInfoGainNodeSplit(df)
        
    if node is None:
        clValue,counts = np.unique(df[targetattr],return_counts=True)  
        return clValue[np.argmax(counts)]

    print (node)
    
    #Create an empty dictionary to create tree    
    if tree is None:                    
        tree={}
        tree[node] = {}
        
    if node in catagorical:
        #Get distinct value of that attribute e.g Salary is node and Low,Med and High are values
        attValue = np.unique(df[node])


       #We make loop to construct a tree by calling this function recursively. 
        #In this we check if the subset is pure and stops if it is pure. 

        for value in attValue:
            subtable = get_subtableCat(df,node,value)
            clValue,counts = np.unique(subtable[targetattr],return_counts=True)                        

            if len(counts)==1:#Checking purity of subset
                tree[node][value] = clValue[0]
            else:        
                tree[node][value] = treeBuilder(subtable) #Calling the function recursively 
                
    elif node in numerical:
        left_subtable , right_subtable = get_subtableNum(df,node,split)
        
        clValue,counts = np.unique(left_subtable[targetattr],return_counts=True)                      
        
        if len(counts)==1:#Checking purity of subset
            tree[node][split] = clValue[0]
        else:        
            tree[node][split] = treeBuilder(left_subtable) #Calling the function recursively 
            
        clValue,counts = np.unique(right_subtable[targetattr],return_counts=True)                        
        
        if len(counts)==1:#Checking purity of subset
            tree[node][float(split) + 0.00002] = clValue[0]
        else:        
            tree[node][float(split) + 0.00002] = treeBuilder(right_subtable) #Calling the function recursively 
            
    return tree

# %%
import numpy as np
import pandas as pd
import pprint
eps = np.finfo(float).eps
true_positive = 0
true_negative = 0
false_positive = 0
false_negative = 0
from numpy import log2 as log
targetattr = "left"
dataSet = pd.read_csv("train.csv")
numerical = ['satisfaction_level' , 'last_evaluation' , 'number_project' , 'average_montly_hours' , 'time_spend_company']
catagorical = ['Work_accident' , 'promotion_last_5years' , 'sales' , 'salary']
# reading csv file  
trainingSet , validationSet = np.split(dataSet,[int(0.8*len(dataSet))])
# print trainingSet
tree = treeBuilder(trainingSet)
pprint.pprint(tree)
# Out:
# satisfaction_level
# satisfaction_level
# number_project
# last_evaluation
# last_evaluation
# average_montly_hours
# satisfaction_level
# average_montly_hours
# salary
# sales
# sales
# average_montly_hours
# average_montly_hours
# satisfaction_level
# average_montly_hours
# satisfaction_level
# satisfaction_level
# average_montly_hours
# last_evaluation
# last_evaluation
# satisfaction_level
# last_evaluation
# number_project
# average_montly_hours
# sales
# satisfaction_level
# last_evaluation
# satisfaction_level
# last_evaluation
# last_evaluation
# satisfaction_level
# satisfaction_level
# satisfaction_level
# number_project
# average_montly_hours
# last_evaluation
# last_evaluation
# salary
# satisfaction_level
# last_evaluation
# satisfaction_level
# satisfaction_level
# satisfaction_level
# number_project
# satisfaction_level
# satisfaction_level
# satisfaction_level
# time_spend_company
# last_evaluation
# satisfaction_level
# average_montly_hours
# satisfaction_level
# satisfaction_level
# time_spend_company
# last_evaluation
# average_montly_hours
# last_evaluation
# satisfaction_level
# last_evaluation
# average_montly_hours
# last_evaluation
# average_montly_hours
# average_montly_hours
# average_montly_hours
# average_montly_hours
# satisfaction_level
# salary
# last_evaluation
# number_project
# last_evaluation
# average_montly_hours
# salary
# satisfaction_level
# satisfaction_level
# satisfaction_level
# average_montly_hours
# average_montly_hours
# last_evaluation
# satisfaction_level
# average_montly_hours
# average_montly_hours
# average_montly_hours
# last_evaluation
# satisfaction_level
# last_evaluation
# last_evaluation
# last_evaluation
# time_spend_company
# number_project
# average_montly_hours
# time_spend_company
# number_project
# average_montly_hours
# sales
# last_evaluation
# last_evaluation
# average_montly_hours
# last_evaluation
# satisfaction_level
# last_evaluation
# last_evaluation
# satisfaction_level
# satisfaction_level
# average_montly_hours
# satisfaction_level
# average_montly_hours
# sales
# satisfaction_level
# average_montly_hours
# last_evaluation
# number_project
# average_montly_hours
# average_montly_hours
# satisfaction_level
# satisfaction_level
# satisfaction_level
# last_evaluation
# satisfaction_level
# last_evaluation
# average_montly_hours
# average_montly_hours
# satisfaction_level
# satisfaction_level
# last_evaluation
# average_montly_hours
# last_evaluation
# satisfaction_level
# satisfaction_level
# last_evaluation
# number_project
# last_evaluation
# last_evaluation
# salary
# number_project
# last_evaluation
# last_evaluation
# satisfaction_level
# average_montly_hours
# average_montly_hours
# average_montly_hours
# satisfaction_level
# satisfaction_level
# sales
# number_project
# satisfaction_level
# satisfaction_level
# last_evaluation
# last_evaluation
# last_evaluation
# satisfaction_level
# number_project
# salary
# satisfaction_level
# last_evaluation
# satisfaction_level
# average_montly_hours
# satisfaction_level
# satisfaction_level
# last_evaluation
# last_evaluation
# last_evaluation
# satisfaction_level
# satisfaction_level
# number_project
# Work_accident
# satisfaction_level
# satisfaction_level
# last_evaluation
# last_evaluation
# satisfaction_level
# average_montly_hours
# salary
# satisfaction_level
# average_montly_hours
# average_montly_hours
# satisfaction_level
# number_project
# satisfaction_level
# sales
# average_montly_hours
# satisfaction_level
# satisfaction_level
# satisfaction_level
# satisfaction_level
# last_evaluation
# time_spend_company
# satisfaction_level
# last_evaluation
# average_montly_hours
# average_montly_hours
# satisfaction_level
# number_project
# salary
# last_evaluation
# last_evaluation
# sales
# average_montly_hours
# last_evaluation
# average_montly_hours
# last_evaluation
# number_project
# satisfaction_level
# satisfaction_level
# satisfaction_level
# satisfaction_level
# average_montly_hours
# satisfaction_level
# last_evaluation
# satisfaction_level
# last_evaluation
# average_montly_hours
# satisfaction_level
# last_evaluation
# salary
# satisfaction_level
# average_montly_hours
# satisfaction_level
# average_montly_hours
# time_spend_company
# number_project
# average_montly_hours
# salary
# sales
# satisfaction_level
# last_evaluation
# number_project
# satisfaction_level
# satisfaction_level
# salary
# number_project
# sales
# satisfaction_level
# satisfaction_level
# satisfaction_level
# satisfaction_level
# satisfaction_level
# number_project
# average_montly_hours
# time_spend_company
# number_project
# average_montly_hours
# satisfaction_level
# sales
# satisfaction_level
# last_evaluation
# number_project
# satisfaction_level
# salary
# last_evaluation
# average_montly_hours
# satisfaction_level
# last_evaluation
# {'satisfaction_level': {0.46: {'satisfaction_level': {0.11: 1,
#                                                       0.11002: {'number_project': {2: {'last_evaluation': {0.57: {'last_evaluation': {0.44: 0,
#                                                                                                                                       0.44002: {'average_montly_hours': {161: {'satisfaction_level': {0.31: 0,
#                                                                                                                                                                                                       0.31002: {'average_montly_hours': {125: 0,
#                                                                                                                                                                                                                                          125.00002: {'salary': {'high': {'sales': {'IT': 0,
#                                                                                                                                                                                                                                                                                    'RandD': 1,
#                                                                                                                                                                                                                                                                                    'accounting': 1,
#                                                                                                                                                                                                                                                                                    'hr': 1,
#                                                                                                                                                                                                                                                                                    'marketing': 1,
#                                                                                                                                                                                                                                                                                    'product_mng': 1,
#                                                                                                                                                                                                                                                                                    'sales': 1,
#                                                                                                                                                                                                                                                                                    'support': 1,
#                                                                                                                                                                                                                                                                                    'technical': 1}},
#                                                                                                                                                                                                                                                                 'low': {'sales': {'IT': 1,
#                                                                                                                                                                                                                                                                                   'RandD': 1,
#                                                                                                                                                                                                                                                                                   'accounting': 1,
#                                                                                                                                                                                                                                                                                   'hr': 1,
#                                                                                                                                                                                                                                                                                   'management': 1,
#                                                                                                                                                                                                                                                                                   'marketing': 1,
#                                                                                                                                                                                                                                                                                   'product_mng': 1,
#                                                                                                                                                                                                                                                                                   'sales': {'average_montly_hours': {150: 1,
#                                                                                                                                                                                                                                                                                                                      150.00002: {'average_montly_hours': {151: {'satisfaction_level': {0.41: 1,
#                                                                                                                                                                                                                                                                                                                                                                                        0.41002: 0}},
#                                                                                                                                                                                                                                                                                                                                                           151.00002: 1}}}},
#                                                                                                                                                                                                                                                                                   'support': {'average_montly_hours': {132: {'satisfaction_level': {0.39: 0,
#                                                                                                                                                                                                                                                                                                                                                     0.39002000000000003: 1}},
#                                                                                                                                                                                                                                                                                                                        132.00002: 1}},
#                                                                                                                                                                                                                                                                                   'technical': 1}},
#                                                                                                                                                                                                                                                                 'medium': 1}}}}}},
#                                                                                                                                                                          161.00002: {'satisfaction_level': {0.41: 0,
#                                                                                                                                                                                                             0.41002: {'average_montly_hours': {219: 0,
#                                                                                                                                                                                                                                                219.00002: 1}}}}}}}},
#                                                                                                            0.57002: {'last_evaluation': {0.77: 0,
#                                                                                                                                          0.77002: {'last_evaluation': {0.78: 1,
#                                                                                                                                                                        0.78002: {'satisfaction_level': {0.43: 0,
#                                                                                                                                                                                                         0.43002: {'last_evaluation': {0.82: 0,
#                                                                                                                                                                                                                                       0.82002: 1}}}}}}}}}},
#                                                                                    2.00002: {'number_project': {6: {'average_montly_hours': {287: {'sales': {'IT': {'satisfaction_level': {0.14: {'last_evaluation': {0.55: {'satisfaction_level': {0.12: 0,
#                                                                                                                                                                                                                                                     0.12002: 1}},
#                                                                                                                                                                                                                       0.5500200000000001: 0}},
#                                                                                                                                                                                            0.14002: 0}},
#                                                                                                                                                              'RandD': {'last_evaluation': {0.99: {'last_evaluation': {0.87: {'satisfaction_level': {0.14: {'satisfaction_level': {0.13: 0,
#                                                                                                                                                                                                                                                                                   0.13002: 1}},
#                                                                                                                                                                                                                                                     0.14002: 0}},
#                                                                                                                                                                                                                       0.87002: {'satisfaction_level': {0.29: 0,
#                                                                                                                                                                                                                                                        0.29002: {'number_project': {3: 0,
#                                                                                                                                                                                                                                                                                     3.00002: 1}}}}}},
#                                                                                                                                                                                            0.99002: 1}},
#                                                                                                                                                              'accounting': {'average_montly_hours': {186: 0,
#                                                                                                                                                                                                      186.00002: {'last_evaluation': {0.95: {'last_evaluation': {0.65: {'salary': {'high': 0,
#                                                                                                                                                                                                                                                                                   'low': {'satisfaction_level': {0.24: 0,
#                                                                                                                                                                                                                                                                                                                  0.24001999999999998: 1}},
#                                                                                                                                                                                                                                                                                   'medium': {'last_evaluation': {0.54: 0,
#                                                                                                                                                                                                                                                                                                                  0.5400200000000001: {'satisfaction_level': {0.31: 1,
#                                                                                                                                                                                                                                                                                                                                                              0.31002: 0}}}}}},
#                                                                                                                                                                                                                                                                 0.65002: 0}},
#                                                                                                                                                                                                                                      0.95002: 1}}}},
#                                                                                                                                                              'hr': 0,
#                                                                                                                                                              'management': {'satisfaction_level': {0.39: 0,
#                                                                                                                                                                                                    0.39002000000000003: {'satisfaction_level': {0.42: 1,
#                                                                                                                                                                                                                                                 0.42002: 0}}}},
#                                                                                                                                                              'marketing': 0,
#                                                                                                                                                              'product_mng': {'number_project': {5: 0,
#                                                                                                                                                                                                 5.00002: {'satisfaction_level': {0.28: 0,
#                                                                                                                                                                                                                                  0.28002000000000005: {'satisfaction_level': {0.31: 1,
#                                                                                                                                                                                                                                                                               0.31002: {'satisfaction_level': {0.32: 0,
#                                                                                                                                                                                                                                                                                                                0.32002: 1}}}}}}}},
#                                                                                                                                                              'sales': {'time_spend_company': {5: {'last_evaluation': {0.53: 0,
#                                                                                                                                                                                                                       0.53002: {'satisfaction_level': {0.3: {'average_montly_hours': {231: 0,
#                                                                                                                                                                                                                                                                                       231.00002: {'satisfaction_level': {0.2: {'satisfaction_level': {0.13: 0,
#                                                                                                                                                                                                                                                                                                                                                       0.13002: {'time_spend_company': {3: {'last_evaluation': {0.57: 0,
#                                                                                                                                                                                                                                                                                                                                                                                                                0.57002: 1}},
#                                                                                                                                                                                                                                                                                                                                                                                        3.00002: {'average_montly_hours': {275: {'last_evaluation': {0.55: {'satisfaction_level': {0.14: 0,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.14002: 1}},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                     0.5500200000000001: 0}},
#                                                                                                                                                                                                                                                                                                                                                                                                                           275.00002: 1}}}}}},
#                                                                                                                                                                                                                                                                                                                          0.20002: 0}}}},
#                                                                                                                                                                                                                                                        0.30002: {'last_evaluation': {0.54: 1,
#                                                                                                                                                                                                                                                                                      0.5400200000000001: {'average_montly_hours': {137: 0,
#                                                                                                                                                                                                                                                                                                                                    137.00002: {'last_evaluation': {0.64: 0,
#                                                                                                                                                                                                                                                                                                                                                                    0.64002: {'average_montly_hours': {149: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                       149.00002: {'average_montly_hours': {169: 0,
#                                                                                                                                                                                                                                                                                                                                                                                                                                            169.00002: {'average_montly_hours': {172: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 172.00002: {'average_montly_hours': {192: 0,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      192.00002: {'satisfaction_level': {0.34: 0,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.34002000000000004: {'salary': {'low': {'last_evaluation': {0.68: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.6800200000000001: 0}},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'medium': 1}}}}}}}}}}}}}}}}}}}}}},
#                                                                                                                                                                                               5.00002: 0}},
#                                                                                                                                                              'support': {'number_project': {5: {'last_evaluation': {0.99: 0,
#                                                                                                                                                                                                                     0.99002: 1}},
#                                                                                                                                                                                             5.00002: {'average_montly_hours': {219: {'salary': {'high': {'satisfaction_level': {0.15: 1,
#                                                                                                                                                                                                                                                                                 0.15002: 0}},
#                                                                                                                                                                                                                                                 'low': {'satisfaction_level': {0.2: {'satisfaction_level': {0.13: 1,
#                                                                                                                                                                                                                                                                                                             0.13002: 0}},
#                                                                                                                                                                                                                                                                                0.20002: 1}},
#                                                                                                                                                                                                                                                 'medium': 0}},
#                                                                                                                                                                                                                                219.00002: 0}}}},
#                                                                                                                                                              'technical': {'average_montly_hours': {237: {'average_montly_hours': {236: {'last_evaluation': {0.85: {'satisfaction_level': {0.14: {'average_montly_hours': {158: 1,
#                                                                                                                                                                                                                                                                                                                            158.00002: 0}},
#                                                                                                                                                                                                                                                                                            0.14002: {'average_montly_hours': {197: 0,
#                                                                                                                                                                                                                                                                                                                               197.00002: {'average_montly_hours': {199: 1,
#                                                                                                                                                                                                                                                                                                                                                                    199.00002: {'last_evaluation': {0.46: {'satisfaction_level': {0.25: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                  0.25002: 0}},
#                                                                                                                                                                                                                                                                                                                                                                                                    0.46002000000000004: 0}}}}}}}},
#                                                                                                                                                                                                                                                              0.85002: {'last_evaluation': {0.87: 1,
#                                                                                                                                                                                                                                                                                            0.87002: {'last_evaluation': {0.9: {'last_evaluation': {0.88: 0,
#                                                                                                                                                                                                                                                                                                                                                    0.88002: 1}},
#                                                                                                                                                                                                                                                                                                                          0.90002: 0}}}}}},
#                                                                                                                                                                                                                                    236.00002: 1}},
#                                                                                                                                                                                                     237.00002: 0}}}},
#                                                                                                                                              287.00002: 1}},
#                                                                                                                 6.00002: 1}}}}}},
#                         0.46002000000000004: {'time_spend_company': {4: {'number_project': {5: {'average_montly_hours': {287: {'time_spend_company': {3: {'number_project': {2: {'average_montly_hours': {167: 0,
#                                                                                                                                                                                                           167.00002: {'sales': {'IT': {'last_evaluation': {0.96: 0,
#                                                                                                                                                                                                                                                            0.96002: 1}},
#                                                                                                                                                                                                                                 'RandD': {'last_evaluation': {0.9: 0,
#                                                                                                                                                                                                                                                               0.90002: 1}},
#                                                                                                                                                                                                                                 'accounting': 0,
#                                                                                                                                                                                                                                 'hr': 0,
#                                                                                                                                                                                                                                 'management': 0,
#                                                                                                                                                                                                                                 'marketing': 0,
#                                                                                                                                                                                                                                 'product_mng': 0,
#                                                                                                                                                                                                                                 'sales': {'average_montly_hours': {168: 1,
#                                                                                                                                                                                                                                                                    168.00002: {'last_evaluation': {0.47: {'satisfaction_level': {0.56: 0,
#                                                                                                                                                                                                                                                                                                                                  0.5600200000000001: 1}},
#                                                                                                                                                                                                                                                                                                    0.47002: 0}}}},
#                                                                                                                                                                                                                                 'support': {'last_evaluation': {0.79: 0,
#                                                                                                                                                                                                                                                                 0.7900200000000001: {'last_evaluation': {0.86: {'satisfaction_level': {0.79: {'satisfaction_level': {0.65: 1,
#                                                                                                                                                                                                                                                                                                                                                                      0.65002: 0}},
#                                                                                                                                                                                                                                                                                                                                        0.7900200000000001: 1}},
#                                                                                                                                                                                                                                                                                                          0.86002: 0}}}},
#                                                                                                                                                                                                                                 'technical': {'average_montly_hours': {252: {'satisfaction_level': {0.48: 1,
#                                                                                                                                                                                                                                                                                                     0.48002: 0}},
#                                                                                                                                                                                                                                                                        252.00002: {'average_montly_hours': {255: 1,
#                                                                                                                                                                                                                                                                                                             255.00002: 0}}}}}}}},
#                                                                                                                                                                              2.00002: {'sales': {'IT': 0,
#                                                                                                                                                                                                  'RandD': 0,
#                                                                                                                                                                                                  'accounting': {'satisfaction_level': {0.5: {'average_montly_hours': {138: 1,
#                                                                                                                                                                                                                                                                       138.00002: 0}},
#                                                                                                                                                                                                                                        0.50002: 0}},
#                                                                                                                                                                                                  'hr': {'last_evaluation': {0.92: 0,
#                                                                                                                                                                                                                             0.9200200000000001: {'number_project': {4: 0,
#                                                                                                                                                                                                                                                                     4.00002: {'average_montly_hours': {163: 1,
#                                                                                                                                                                                                                                                                                                        163.00002: 0}}}}}},
#                                                                                                                                                                                                  'management': {'average_montly_hours': {274: 0,
# ...
#                                                                                                                                                                                                                                                                            'sales': 1,
#                                                                                                                                                                                                                                                                            'support': 1,
#                                                                                                                                                                                                                                                                            'technical': 0}},
#                                                                                                                                                                                                                                                          'medium': {'satisfaction_level': {0.81: 0,
#                                                                                                                                                                                                                                                                                            0.8100200000000001: 1}}}}}},
#                                                                                                                                                                                                      3.00002: 0}},
#                                                                                                                                                                               5.00002: {'last_evaluation': {0.99: {'number_project': {5: 0,
#                                                                                                                                                                                                                                       5.00002: {'satisfaction_level': {0.54: 1,
#                                                                                                                                                                                                                                                                        0.5400200000000001: 0}}}},
#                                                                                                                                                                                                             0.99002: 1}}}},
#                                                                                                                                                  216.00002: {'satisfaction_level': {0.71: {'salary': {'high': 0,
#                                                                                                                                                                                                       'low': {'number_project': {2: 1,
#                                                                                                                                                                                                                                  2.00002: {'sales': {'accounting': {'satisfaction_level': {0.55: 0,
#                                                                                                                                                                                                                                                                                            0.5500200000000001: {'satisfaction_level': {0.63: 1,
#                                                                                                                                                                                                                                                                                                                                        0.63002: 0}}}},
#                                                                                                                                                                                                                                                      'management': 0,
#                                                                                                                                                                                                                                                      'product_mng': 1,
#                                                                                                                                                                                                                                                      'sales': 0,
#                                                                                                                                                                                                                                                      'technical': {'satisfaction_level': {0.48: 1,
#                                                                                                                                                                                                                                                                                           0.48002: 0}}}}}},
#                                                                                                                                                                                                       'medium': {'satisfaction_level': {0.65: 0,
#                                                                                                                                                                                                                                         0.65002: {'satisfaction_level': {0.66: 1,
#                                                                                                                                                                                                                                                                          0.66002: 0}}}}}},
#                                                                                                                                                                                     0.71002: {'number_project': {3: {'average_montly_hours': {286: 0,
#                                                                                                                                                                                                                                               286.00002: 1}},
#                                                                                                                                                                                                                  3.00002: {'time_spend_company': {6: {'number_project': {5: {'average_montly_hours': {238: {'satisfaction_level': {0.91: {'sales': {'IT': 1,
#                                                                                                                                                                                                                                                                                                                                                     'RandD': 1,
#                                                                                                                                                                                                                                                                                                                                                     'accounting': 1,
#                                                                                                                                                                                                                                                                                                                                                     'hr': 1,
#                                                                                                                                                                                                                                                                                                                                                     'management': {'satisfaction_level': {0.88: 1,
#                                                                                                                                                                                                                                                                                                                                                                                           0.88002: 0}},
#                                                                                                                                                                                                                                                                                                                                                     'marketing': 1,
#                                                                                                                                                                                                                                                                                                                                                     'product_mng': 1,
#                                                                                                                                                                                                                                                                                                                                                     'sales': {'last_evaluation': {0.87: {'number_project': {4: {'satisfaction_level': {0.78: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                        0.78002: 0}},
#                                                                                                                                                                                                                                                                                                                                                                                                             4.00002: 1}},
#                                                                                                                                                                                                                                                                                                                                                                                   0.87002: 1}},
#                                                                                                                                                                                                                                                                                                                                                     'support': 1,
#                                                                                                                                                                                                                                                                                                                                                     'technical': {'salary': {'high': 1,
#                                                                                                                                                                                                                                                                                                                                                                              'low': {'last_evaluation': {0.85: 0,
#                                                                                                                                                                                                                                                                                                                                                                                                          0.85002: {'average_montly_hours': {235: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                             235.00002: {'satisfaction_level': {0.81: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.8100200000000001: 0}}}}}},
#                                                                                                                                                                                                                                                                                                                                                                              'medium': 1}}}},
#                                                                                                                                                                                                                                                                                                                                    0.91002: {'last_evaluation': {0.87: 1,
#                                                                                                                                                                                                                                                                                                                                                                  0.87002: 0}}}},
#                                                                                                                                                                                                                                                                                                       238.00002: 1}},
#                                                                                                                                                                                                                                                                          5.00002: 0}},
#                                                                                                                                                                                                                                                   6.00002: 0}}}}}}}}}}}}}}

# %%
def predict(tree , row):
    #This function is used to predict for any input variable 
    
    #Recursively we go through the tree that we built earlier
    for nodes in tree.keys():        
        value = row[nodes]
        if nodes in catagorical:
            if value in list((tree[nodes]).keys()):
                tree = tree[nodes][value]
            else:
                zeros = 0
                ones = 0
                for i in tree[nodes].keys():
                    if tree[nodes][i] == 0:
                        zeros += 1
                    elif tree[nodes][i] == 1:
                        ones += 1
                if zeros > ones:
                    return 0
                else:
                    return 1
        else:
            binaryValue = list(tree[nodes].keys())
            if value <= binaryValue[0]:
                tree = tree[nodes][binaryValue[0]]
            else:
                tree = tree[nodes][binaryValue[1]]
        prediction = 0
        if type(tree) is dict:
            prediction = predict(tree , row)
        else:
            prediction = tree
            break;   
            
    return prediction

# %%
def validate(tree, df):
    true_positive = 0
    true_negative = 0 
    false_negative = 0
    false_positive = 0
    for index, row in df.iterrows():
        value = predict(tree, row)
        if value == row[targetattr]:
            if value == 1:
                true_positive += 1
            else:
                true_negative += 1
        else:
            if value == 1:
                false_positive += 1
            else:
                false_negative += 1
    return true_positive , true_negative , false_negative, false_positive

# %%
def accuracy(true_positive , true_negative , false_negative, false_positive):
    return ((true_positive + true_negative)*100)/(true_positive + true_negative + false_positive + false_negative + eps)

# %%
def recall(true_positive , false_negative):
    return true_positive*100/(true_positive +  false_negative+ eps)

# %%
def precision(true_positive , false_positive):
    return true_positive*100/(true_positive +  false_positive + eps)

# %%
def f1score(recall , prescision):
    return 2/(1/(recall)+1/(prescision))

# %%
true_positive , true_negative , false_negative, false_positive = validate(tree , validationSet)
acc = accuracy(true_positive , true_negative , false_negative, false_positive)
rec = recall(true_positive , false_negative)
pre = precision(true_positive , false_positive)
f1 = f1score(rec, pre)

print("ACCURACY%: ", acc)
print("RECALL: ", rec)
print("PRECISION: ", pre)
print("F1-score: ", f1)
# Out:
# ACCURACY%:  97.77580071174377
# RECALL:  95.77981651376147
# PRECISION:  95.08196721311475
# F1-score:  95.42961608775138
