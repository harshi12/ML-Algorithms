# %%
def maxInfoGainNodeSplit(df):
    attributes = list(df)
    maxGain = 0.0
    gain = 0.0
    split = 0
    temp = 0.0
    entropybefore = entropy(df)
    for attr in attributes:
        if attr != targetattr:
            if attr in catagorical:
                gain = entropybefore - I(df,attr)
                if maxGain < gain:
                    maxGain = gain
                    node = attr
                    split = 0
            else:
                temp, ImpurityNum = InumMin(df,attr)
                gain = entropybefore - ImpurityNum
                if maxGain < gain:
                    maxGain = gain
                    node = attr
                    split = temp
    if maxGain == 0.0:
        return None , split
    else:
        return node , split

# %%
def entropy(df):
    entropy = 0
    uniqueSet = df[targetattr].unique()
    for elem in uniqueSet:
        fraction = df[targetattr].value_counts()[elem]/float(len(df)+ eps)
        entropy += -fraction*np.log2(fraction + eps)
    return entropy

# %%
def entropy_attr(num_of_ones , total):
    fraction1 = num_of_ones/(total + eps)
    fraction2 = (total - num_of_ones)/(total + eps)
    entropy = -fraction1*np.log2(fraction1 + eps) - fraction2*np.log2(fraction2 + eps)
    return entropy

# %%
import sys

def InumMin(df , attribute):
    target_variables = df[targetattr].unique()  #This gives all 'Yes' and 'No'
#     print("TARGET VARS : ",target_variables[0])
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    
    variables.sort()
    
    split = 0
    minInum = sys.float_info.max
    total_ones = df[targetattr].value_counts()[target_variables[0]]
    arr = df[[attribute, targetattr]].values
    arr = arr[np.argsort(arr[:, 0])]

    nRows = arr.shape[0]

    num_of_ones = 0
    i = 0
    for variable in variables:
        impurity = 0.0
        while (i < nRows and arr[i][0] == variable) :
            if arr[i][1] == target_variables[0]:
                num_of_ones += 1
            i += 1
        num_left = i
        fraction_left = num_left/(nRows + eps)
        if num_left == 0:
            impurity += 0.0
        else:
            impurity += fraction_left*entropy_attr(num_of_ones , num_left) 
            
        num_right = nRows - num_left
        fraction_right = num_right/(nRows + eps)
        if num_right == 0:
            impurity += 0.0
        else:
            impurity += fraction_right*entropy_attr(total_ones - num_of_ones , num_right) 
        
        if minInum > impurity:
            minInum = impurity
            split = variable
        
    return split , minInum

# %%
def I(df , attribute):
    target_variables = df[targetattr].unique()  #This gives all 'Yes' and 'No'
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    den = len(df[attribute])
    impurity = 0
    for variable in variables:
        num = len(df[attribute][df[attribute] == variable])
        fraction = num/(den + eps)
        if num == 0:
            impurity += 0.0
        else:
            impurity += fraction*entropy(df[df[attribute] == variable]) 
    return impurity

# %%
def get_subtableCat(df, node,value):
    return df[df[node] == value].reset_index(drop=True)

# %%
def get_subtableNum(df, node, value):
    return df[df[node] <= value].reset_index(drop=True) , df[df[node] > value].reset_index(drop=True)

# %%
def treeBuilder(df, depth ,tree=None):     
    #Here we build our decision tree   
    #Get attribute with maximum information gain
    node, split = maxInfoGainNodeSplit(df)
    clValue,counts = np.unique(df[targetattr],return_counts=True)  
    if node is None:
        return clValue[np.argmax(counts)]

    print (node)
    
    #Create an empty dictionary to create tree    
    if tree is None:                    
        tree={}
        tree[node] = {}
        tree['DEPTH'] = depth
        tree['CUR_VALUE'] = clValue[np.argmax(counts)]
        
    if node in catagorical:
        #Get distinct value of that attribute e.g Salary is node and Low,Med and High are values
        attValue = np.unique(df[node])


       #We make loop to construct a tree by calling this function recursively. 
        #In this we check if the subset is pure and stops if it is pure. 

        for value in attValue:
            subtable = get_subtableCat(df,node,value)
            clValue,counts = np.unique(subtable[targetattr],return_counts=True)                        

            if len(counts)==1:#Checking purity of subset
                tree[node][value] = clValue[0]
            else:        
                tree[node][value] = treeBuilder(subtable , depth + 1) #Calling the function recursively 
                
    elif node in numerical:
        left_subtable , right_subtable = get_subtableNum(df,node,split)
        
        clValue,counts = np.unique(left_subtable[targetattr],return_counts=True)                      
        
        if len(counts)==1:#Checking purity of subset
            tree[node][split] = clValue[0]
        else:        
            tree[node][split] = treeBuilder(left_subtable , depth + 1) #Calling the function recursively 
            
        clValue,counts = np.unique(right_subtable[targetattr],return_counts=True)                        
        
        if len(counts)==1:#Checking purity of subset
            tree[node][split + 0.00002] = clValue[0]
        else:        
            tree[node][split + 0.00002] = treeBuilder(right_subtable , depth + 1) #Calling the function recursively 
            
    return tree

# %%
import numpy as np
import pandas as pd
import pprint
eps = np.finfo(float).eps
true_positive = 0
true_negative = 0
false_positive = 0
false_negative = 0
from numpy import log2 as log
targetattr = "left"
dataSet = pd.read_csv("train.csv")
numerical = ['satisfaction_level' , 'last_evaluation' , 'number_project' , 'average_montly_hours' , 'time_spend_company']
catagorical = ['Work_accident' , 'promotion_last_5years' , 'sales' , 'salary']
# reading csv file  
trainingSet , validationSet = np.split(dataSet,[int(0.8*len(dataSet))])
# print trainingSet
tree = treeBuilder(trainingSet,0)
pprint.pprint(tree)
# Out:
# satisfaction_level
# satisfaction_level
# number_project
# last_evaluation
# last_evaluation
# average_montly_hours
# satisfaction_level
# average_montly_hours
# salary
# sales
# sales
# average_montly_hours
# average_montly_hours
# satisfaction_level
# average_montly_hours
# satisfaction_level
# satisfaction_level
# average_montly_hours
# last_evaluation
# last_evaluation
# satisfaction_level
# last_evaluation
# number_project
# average_montly_hours
# sales
# satisfaction_level
# last_evaluation
# satisfaction_level
# last_evaluation
# last_evaluation
# satisfaction_level
# satisfaction_level
# satisfaction_level
# number_project
# average_montly_hours
# last_evaluation
# last_evaluation
# salary
# satisfaction_level
# last_evaluation
# satisfaction_level
# satisfaction_level
# satisfaction_level
# number_project
# satisfaction_level
# satisfaction_level
# satisfaction_level
# time_spend_company
# last_evaluation
# satisfaction_level
# average_montly_hours
# satisfaction_level
# satisfaction_level
# time_spend_company
# last_evaluation
# average_montly_hours
# last_evaluation
# satisfaction_level
# last_evaluation
# average_montly_hours
# last_evaluation
# average_montly_hours
# average_montly_hours
# average_montly_hours
# average_montly_hours
# satisfaction_level
# salary
# last_evaluation
# number_project
# last_evaluation
# average_montly_hours
# salary
# satisfaction_level
# satisfaction_level
# satisfaction_level
# average_montly_hours
# average_montly_hours
# last_evaluation
# satisfaction_level
# average_montly_hours
# average_montly_hours
# average_montly_hours
# last_evaluation
# satisfaction_level
# last_evaluation
# last_evaluation
# last_evaluation
# time_spend_company
# number_project
# average_montly_hours
# time_spend_company
# number_project
# average_montly_hours
# sales
# last_evaluation
# last_evaluation
# average_montly_hours
# last_evaluation
# satisfaction_level
# last_evaluation
# last_evaluation
# satisfaction_level
# satisfaction_level
# average_montly_hours
# satisfaction_level
# average_montly_hours
# sales
# satisfaction_level
# average_montly_hours
# last_evaluation
# number_project
# average_montly_hours
# average_montly_hours
# satisfaction_level
# satisfaction_level
# satisfaction_level
# last_evaluation
# satisfaction_level
# last_evaluation
# average_montly_hours
# average_montly_hours
# satisfaction_level
# satisfaction_level
# last_evaluation
# average_montly_hours
# last_evaluation
# satisfaction_level
# satisfaction_level
# last_evaluation
# number_project
# last_evaluation
# last_evaluation
# salary
# number_project
# last_evaluation
# last_evaluation
# satisfaction_level
# average_montly_hours
# average_montly_hours
# average_montly_hours
# satisfaction_level
# satisfaction_level
# sales
# number_project
# satisfaction_level
# satisfaction_level
# last_evaluation
# last_evaluation
# last_evaluation
# satisfaction_level
# number_project
# salary
# satisfaction_level
# last_evaluation
# satisfaction_level
# average_montly_hours
# satisfaction_level
# satisfaction_level
# last_evaluation
# last_evaluation
# last_evaluation
# satisfaction_level
# satisfaction_level
# number_project
# Work_accident
# satisfaction_level
# satisfaction_level
# last_evaluation
# last_evaluation
# satisfaction_level
# average_montly_hours
# salary
# satisfaction_level
# average_montly_hours
# average_montly_hours
# satisfaction_level
# number_project
# satisfaction_level
# sales
# average_montly_hours
# satisfaction_level
# satisfaction_level
# satisfaction_level
# satisfaction_level
# last_evaluation
# time_spend_company
# satisfaction_level
# last_evaluation
# average_montly_hours
# average_montly_hours
# satisfaction_level
# number_project
# salary
# last_evaluation
# last_evaluation
# sales
# average_montly_hours
# last_evaluation
# average_montly_hours
# last_evaluation
# number_project
# satisfaction_level
# satisfaction_level
# satisfaction_level
# satisfaction_level
# average_montly_hours
# satisfaction_level
# last_evaluation
# satisfaction_level
# last_evaluation
# average_montly_hours
# satisfaction_level
# last_evaluation
# salary
# satisfaction_level
# average_montly_hours
# satisfaction_level
# average_montly_hours
# time_spend_company
# number_project
# average_montly_hours
# salary
# sales
# satisfaction_level
# last_evaluation
# number_project
# satisfaction_level
# satisfaction_level
# salary
# number_project
# sales
# satisfaction_level
# satisfaction_level
# satisfaction_level
# satisfaction_level
# satisfaction_level
# number_project
# average_montly_hours
# time_spend_company
# number_project
# average_montly_hours
# satisfaction_level
# sales
# satisfaction_level
# last_evaluation
# number_project
# satisfaction_level
# salary
# last_evaluation
# average_montly_hours
# satisfaction_level
# last_evaluation
# {'CUR_VALUE': 0,
#  'DEPTH': 0,
#  'satisfaction_level': {0.46: {'CUR_VALUE': 1,
#                                'DEPTH': 1,
#                                'satisfaction_level': {0.11: 1,
#                                                       0.11002: {'CUR_VALUE': 0,
#                                                                 'DEPTH': 2,
#                                                                 'number_project': {2: {'CUR_VALUE': 1,
#                                                                                        'DEPTH': 3,
#                                                                                        'last_evaluation': {0.57: {'CUR_VALUE': 1,
#                                                                                                                   'DEPTH': 4,
#                                                                                                                   'last_evaluation': {0.44: 0,
#                                                                                                                                       0.44002: {'CUR_VALUE': 1,
#                                                                                                                                                 'DEPTH': 5,
#                                                                                                                                                 'average_montly_hours': {161: {'CUR_VALUE': 1,
#                                                                                                                                                                                'DEPTH': 6,
#                                                                                                                                                                                'satisfaction_level': {0.31: 0,
#                                                                                                                                                                                                       0.31002: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                 'DEPTH': 7,
#                                                                                                                                                                                                                 'average_montly_hours': {125: 0,
#                                                                                                                                                                                                                                          125.00002: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                      'DEPTH': 8,
#                                                                                                                                                                                                                                                      'salary': {'high': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                          'DEPTH': 9,
#                                                                                                                                                                                                                                                                          'sales': {'IT': 0,
#                                                                                                                                                                                                                                                                                    'RandD': 1,
#                                                                                                                                                                                                                                                                                    'accounting': 1,
#                                                                                                                                                                                                                                                                                    'hr': 1,
#                                                                                                                                                                                                                                                                                    'marketing': 1,
#                                                                                                                                                                                                                                                                                    'product_mng': 1,
#                                                                                                                                                                                                                                                                                    'sales': 1,
#                                                                                                                                                                                                                                                                                    'support': 1,
#                                                                                                                                                                                                                                                                                    'technical': 1}},
#                                                                                                                                                                                                                                                                 'low': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                         'DEPTH': 9,
#                                                                                                                                                                                                                                                                         'sales': {'IT': 1,
#                                                                                                                                                                                                                                                                                   'RandD': 1,
#                                                                                                                                                                                                                                                                                   'accounting': 1,
#                                                                                                                                                                                                                                                                                   'hr': 1,
#                                                                                                                                                                                                                                                                                   'management': 1,
#                                                                                                                                                                                                                                                                                   'marketing': 1,
#                                                                                                                                                                                                                                                                                   'product_mng': 1,
#                                                                                                                                                                                                                                                                                   'sales': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                             'DEPTH': 10,
#                                                                                                                                                                                                                                                                                             'average_montly_hours': {150: 1,
#                                                                                                                                                                                                                                                                                                                      150.00002: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                  'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                                  'average_montly_hours': {151: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                 'DEPTH': 12,
#                                                                                                                                                                                                                                                                                                                                                                 'satisfaction_level': {0.41: 1,
#                                                                                                                                                                                                                                                                                                                                                                                        0.41002: 0}},
#                                                                                                                                                                                                                                                                                                                                                           151.00002: 1}}}},
#                                                                                                                                                                                                                                                                                   'support': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                               'DEPTH': 10,
#                                                                                                                                                                                                                                                                                               'average_montly_hours': {132: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                              'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                              'satisfaction_level': {0.39: 0,
#                                                                                                                                                                                                                                                                                                                                                     0.39002000000000003: 1}},
#                                                                                                                                                                                                                                                                                                                        132.00002: 1}},
#                                                                                                                                                                                                                                                                                   'technical': 1}},
#                                                                                                                                                                                                                                                                 'medium': 1}}}}}},
#                                                                                                                                                                          161.00002: {'CUR_VALUE': 0,
#                                                                                                                                                                                      'DEPTH': 6,
#                                                                                                                                                                                      'satisfaction_level': {0.41: 0,
#                                                                                                                                                                                                             0.41002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                       'DEPTH': 7,
#                                                                                                                                                                                                                       'average_montly_hours': {219: 0,
#                                                                                                                                                                                                                                                219.00002: 1}}}}}}}},
#                                                                                                            0.57002: {'CUR_VALUE': 0,
#                                                                                                                      'DEPTH': 4,
#                                                                                                                      'last_evaluation': {0.77: 0,
#                                                                                                                                          0.77002: {'CUR_VALUE': 0,
#                                                                                                                                                    'DEPTH': 5,
#                                                                                                                                                    'last_evaluation': {0.78: 1,
#                                                                                                                                                                        0.78002: {'CUR_VALUE': 0,
#                                                                                                                                                                                  'DEPTH': 6,
#                                                                                                                                                                                  'satisfaction_level': {0.43: 0,
#                                                                                                                                                                                                         0.43002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                   'DEPTH': 7,
#                                                                                                                                                                                                                   'last_evaluation': {0.82: 0,
#                                                                                                                                                                                                                                       0.82002: 1}}}}}}}}}},
#                                                                                    2.00002: {'CUR_VALUE': 0,
#                                                                                              'DEPTH': 3,
#                                                                                              'number_project': {6: {'CUR_VALUE': 0,
#                                                                                                                     'DEPTH': 4,
#                                                                                                                     'average_montly_hours': {287: {'CUR_VALUE': 0,
#                                                                                                                                                    'DEPTH': 5,
#                                                                                                                                                    'sales': {'IT': {'CUR_VALUE': 0,
#                                                                                                                                                                     'DEPTH': 6,
#                                                                                                                                                                     'satisfaction_level': {0.14: {'CUR_VALUE': 0,
#                                                                                                                                                                                                   'DEPTH': 7,
#                                                                                                                                                                                                   'last_evaluation': {0.55: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                              'DEPTH': 8,
#                                                                                                                                                                                                                              'satisfaction_level': {0.12: 0,
#                                                                                                                                                                                                                                                     0.12002: 1}},
#                                                                                                                                                                                                                       0.5500200000000001: 0}},
#                                                                                                                                                                                            0.14002: 0}},
#                                                                                                                                                              'RandD': {'CUR_VALUE': 0,
#                                                                                                                                                                        'DEPTH': 6,
#                                                                                                                                                                        'last_evaluation': {0.99: {'CUR_VALUE': 0,
#                                                                                                                                                                                                   'DEPTH': 7,
#                                                                                                                                                                                                   'last_evaluation': {0.87: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                              'DEPTH': 8,
#                                                                                                                                                                                                                              'satisfaction_level': {0.14: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                            'DEPTH': 9,
#                                                                                                                                                                                                                                                            'satisfaction_level': {0.13: 0,
#                                                                                                                                                                                                                                                                                   0.13002: 1}},
#                                                                                                                                                                                                                                                     0.14002: 0}},
#                                                                                                                                                                                                                       0.87002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                 'DEPTH': 8,
#                                                                                                                                                                                                                                 'satisfaction_level': {0.29: 0,
#                                                                                                                                                                                                                                                        0.29002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                  'DEPTH': 9,
#                                                                                                                                                                                                                                                                  'number_project': {3: 0,
#                                                                                                                                                                                                                                                                                     3.00002: 1}}}}}},
#                                                                                                                                                                                            0.99002: 1}},
#                                                                                                                                                              'accounting': {'CUR_VALUE': 0,
#                                                                                                                                                                             'DEPTH': 6,
#                                                                                                                                                                             'average_montly_hours': {186: 0,
#                                                                                                                                                                                                      186.00002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                  'DEPTH': 7,
#                                                                                                                                                                                                                  'last_evaluation': {0.95: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                             'DEPTH': 8,
#                                                                                                                                                                                                                                             'last_evaluation': {0.65: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                        'DEPTH': 9,
#                                                                                                                                                                                                                                                                        'salary': {'high': 0,
#                                                                                                                                                                                                                                                                                   'low': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                           'DEPTH': 10,
#                                                                                                                                                                                                                                                                                           'satisfaction_level': {0.24: 0,
#                                                                                                                                                                                                                                                                                                                  0.24001999999999998: 1}},
#                                                                                                                                                                                                                                                                                   'medium': {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                              'DEPTH': 10,
#                                                                                                                                                                                                                                                                                              'last_evaluation': {0.54: 0,
#                                                                                                                                                                                                                                                                                                                  0.5400200000000001: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                       'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                                       'satisfaction_level': {0.31: 1,
#                                                                                                                                                                                                                                                                                                                                                              0.31002: 0}}}}}},
#                                                                                                                                                                                                                                                                 0.65002: 0}},
#                                                                                                                                                                                                                                      0.95002: 1}}}},
#                                                                                                                                                              'hr': 0,
#                                                                                                                                                              'management': {'CUR_VALUE': 0,
#                                                                                                                                                                             'DEPTH': 6,
#                                                                                                                                                                             'satisfaction_level': {0.39: 0,
#                                                                                                                                                                                                    0.39002000000000003: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                          'DEPTH': 7,
#                                                                                                                                                                                                                          'satisfaction_level': {0.42: 1,
#                                                                                                                                                                                                                                                 0.42002: 0}}}},
#                                                                                                                                                              'marketing': 0,
#                                                                                                                                                              'product_mng': {'CUR_VALUE': 0,
#                                                                                                                                                                              'DEPTH': 6,
#                                                                                                                                                                              'number_project': {5: 0,
#                                                                                                                                                                                                 5.00002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                           'DEPTH': 7,
#                                                                                                                                                                                                           'satisfaction_level': {0.28: 0,
#                                                                                                                                                                                                                                  0.28002000000000005: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                        'DEPTH': 8,
#                                                                                                                                                                                                                                                        'satisfaction_level': {0.31: 1,
#                                                                                                                                                                                                                                                                               0.31002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                         'DEPTH': 9,
#                                                                                                                                                                                                                                                                                         'satisfaction_level': {0.32: 0,
#                                                                                                                                                                                                                                                                                                                0.32002: 1}}}}}}}},
#                                                                                                                                                              'sales': {'CUR_VALUE': 0,
#                                                                                                                                                                        'DEPTH': 6,
#                                                                                                                                                                        'time_spend_company': {5: {'CUR_VALUE': 0,
#                                                                                                                                                                                                   'DEPTH': 7,
#                                                                                                                                                                                                   'last_evaluation': {0.53: 0,
#                                                                                                                                                                                                                       0.53002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                 'DEPTH': 8,
#                                                                                                                                                                                                                                 'satisfaction_level': {0.3: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                              'DEPTH': 9,
#                                                                                                                                                                                                                                                              'average_montly_hours': {231: 0,
#                                                                                                                                                                                                                                                                                       231.00002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                                   'DEPTH': 10,
#                                                                                                                                                                                                                                                                                                   'satisfaction_level': {0.2: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                                                                'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                                'satisfaction_level': {0.13: 0,
#                                                                                                                                                                                                                                                                                                                                                       0.13002: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                                                                                                 'DEPTH': 12,
#                                                                                                                                                                                                                                                                                                                                                                 'time_spend_company': {3: {'CUR_VALUE': 1,
# ...
#                                                                                                                                                                                                                                                                                                                                                     'RandD': 1,
#                                                                                                                                                                                                                                                                                                                                                     'accounting': 1,
#                                                                                                                                                                                                                                                                                                                                                     'hr': 1,
#                                                                                                                                                                                                                                                                                                                                                     'management': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                    'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                                                                    'satisfaction_level': {0.88: 1,
#                                                                                                                                                                                                                                                                                                                                                                                           0.88002: 0}},
#                                                                                                                                                                                                                                                                                                                                                     'marketing': 1,
#                                                                                                                                                                                                                                                                                                                                                     'product_mng': 1,
#                                                                                                                                                                                                                                                                                                                                                     'sales': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                               'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                                                               'last_evaluation': {0.87: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                                          'DEPTH': 12,
#                                                                                                                                                                                                                                                                                                                                                                                          'number_project': {4: {'CUR_VALUE': 0,
#                                                                                                                                                                                                                                                                                                                                                                                                                 'DEPTH': 13,
#                                                                                                                                                                                                                                                                                                                                                                                                                 'satisfaction_level': {0.78: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                        0.78002: 0}},
#                                                                                                                                                                                                                                                                                                                                                                                                             4.00002: 1}},
#                                                                                                                                                                                                                                                                                                                                                                                   0.87002: 1}},
#                                                                                                                                                                                                                                                                                                                                                     'support': 1,
#                                                                                                                                                                                                                                                                                                                                                     'technical': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                   'DEPTH': 11,
#                                                                                                                                                                                                                                                                                                                                                                   'salary': {'high': 1,
#                                                                                                                                                                                                                                                                                                                                                                              'low': {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                                      'DEPTH': 12,
#                                                                                                                                                                                                                                                                                                                                                                                      'last_evaluation': {0.85: 0,
#                                                                                                                                                                                                                                                                                                                                                                                                          0.85002: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                    'DEPTH': 13,
#                                                                                                                                                                                                                                                                                                                                                                                                                    'average_montly_hours': {235: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                             235.00002: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                         'DEPTH': 14,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                         'satisfaction_level': {0.81: 1,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.8100200000000001: 0}}}}}},
#                                                                                                                                                                                                                                                                                                                                                                              'medium': 1}}}},
#                                                                                                                                                                                                                                                                                                                                    0.91002: {'CUR_VALUE': 1,
#                                                                                                                                                                                                                                                                                                                                              'DEPTH': 10,
#                                                                                                                                                                                                                                                                                                                                              'last_evaluation': {0.87: 1,
#                                                                                                                                                                                                                                                                                                                                                                  0.87002: 0}}}},
#                                                                                                                                                                                                                                                                                                       238.00002: 1}},
#                                                                                                                                                                                                                                                                          5.00002: 0}},
#                                                                                                                                                                                                                                                   6.00002: 0}}}}}}}}}}}}}}

# %%
def predict(tree , row, depth):
    #This function is used to predict for any input variable 
    
    #Recursively we go through the tree that we built earlier
    if tree['DEPTH'] == depth:
        return tree['CUR_VALUE']
    prediction = 0
    for nodes in tree.keys():  
        if nodes == 'DEPTH' or nodes == 'CUR_VALUE':
            continue
        value = row[nodes]
        if nodes in catagorical:
            if value in list((tree[nodes]).keys()):
                tree = tree[nodes][value]
            else:
                zeros = 0
                ones = 0
                for i in tree[nodes].keys():
                    if tree[nodes][i] == 0:
                        zeros += 1
                    elif tree[nodes][i] == 1:
                        ones += 1
                if zeros > ones:
                    return 0
                else:
                    return 1
        else:
            binaryValue = list(tree[nodes].keys())
            if value <= binaryValue[0]:
                tree = tree[nodes][binaryValue[0]]
            else:
                tree = tree[nodes][binaryValue[1]]
        if type(tree) is dict:
            prediction = predict(tree , row, depth)
        else:
            prediction = tree
            break;   
            
    return prediction

# %%
def validate(tree, df):
    correct = 0
    wrong = 0
    ACC = []
    for i in range(0,22):
        for index, row in df.iterrows():
            if predict(tree, row, i) == row[targetattr]:
                correct += 1
            else:
                wrong += 1
        ACC.append(100.0*correct/(correct + wrong + eps))
    return ACC

# %%
import matplotlib.pyplot as plt

ACC = validate(tree , validationSet)
DEPTH = []
for i in  range(0 , len(ACC)):
    print("Accuracy at depth: "+ str(i) +" is "+ str(ACC[i]) + "%")
    DEPTH.append(i)

plt.figure(num=None, figsize=(8, 6), dpi=200, facecolor='w', edgecolor='k')
# plotting the points  
plt.plot(DEPTH, ACC) 
  
# naming the x axis 
plt.xlabel('Depth') 
# naming the y axis 
plt.ylabel('Accuracy') 
  
# giving a title to my graph 
plt.title('Accuracy-vs-Depth') 
plt.grid(True)

plt.savefig('Plot/Accuracy-vs-Depth.png')

# function to show the plot 
plt.show()

ACC[:] = [100 - x for x in ACC]
plt.figure(num=None, figsize=(8, 6), dpi=200, facecolor='w', edgecolor='k')
# plotting the points  
plt.plot(DEPTH, ACC) 
  
# naming the x axis 
plt.xlabel('Depth') 
# naming the y axis 
plt.ylabel('Error rate') 
  
# giving a title to my graph 
plt.title('Error rate-vs-Depth') 
plt.grid(True)
  
plt.savefig('Plot/Error rate-vs-Depth')

# function to show the plot 
plt.show()
# Out:
# Accuracy at depth: 0 is 75.75622775800711%
# Accuracy at depth: 1 is 78.7144128113879%
# Accuracy at depth: 2 is 79.59667852906287%
# Accuracy at depth: 3 is 83.12944839857651%
# Accuracy at depth: 4 is 85.75622775800711%
# Accuracy at depth: 5 is 87.6408659549229%
# Accuracy at depth: 6 is 89.01881037112354%
# Accuracy at depth: 7 is 90.10231316725978%
# Accuracy at depth: 8 is 90.9648082245947%
# Accuracy at depth: 9 is 91.65480427046263%
# Accuracy at depth: 10 is 92.21125849239728%
# Accuracy at depth: 11 is 92.68609134045077%
# Accuracy at depth: 12 is 93.0810292909937%
# Accuracy at depth: 13 is 93.41319267920692%
# Accuracy at depth: 14 is 93.70106761565836%
# Accuracy at depth: 15 is 93.9557384341637%
# Accuracy at depth: 16 is 94.1804479799037%
# Accuracy at depth: 17 is 94.38018979833926%
# Accuracy at depth: 18 is 94.55890616220266%
# Accuracy at depth: 19 is 94.71975088967972%
# Accuracy at depth: 20 is 94.86527707168277%
# Accuracy at depth: 21 is 94.99757360077645%
